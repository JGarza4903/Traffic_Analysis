# %%
import pandas as pd
import numpy as np

# %%
# Read in our dataset
df = pd.read_csv("CrashData_OpenData.csv")
df.head()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_12696\1458870752.py:2: DtypeWarning: Columns (22,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("CrashData_OpenData.csv")
#             X          Y  OBJECTID        Crash_Severity  County  \
# 0 -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY   CLARK
# 1 -119.673794  39.626433    663734  PROPERTY DAMAGE ONLY  WASHOE
# 2 -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY   CLARK
# 3 -119.633092  39.516952    663736  PROPERTY DAMAGE ONLY  WASHOE
# 4 -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY   CLARK
#
#                Crash_Date  Crash_Year   Crash_Time Primary_Street  Distance  \
# 0  2016/01/04 10:27:00+00        2016  10:27:00 AM          IR15N       1.0
# 1  2016/01/07 05:52:59+00        2016   5:53:00 AM      HUBBLE DR      20.0
# 2  2016/01/04 07:21:59+00        2016   7:22:00 AM          SR573      30.0
# ...

# %%
df.shape
# Out:
# (237338, 52)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=237338, step=1)

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Crash_Severity', 'County', 'Crash_Date',
#        'Crash_Year', 'Crash_Time', 'Primary_Street', 'Distance', 'Dir',
#        'Secondary_Street', 'Weather', 'Fatalities', 'Injured',
#        'Property_Damage_Only', 'Injury_Type', 'Crash_Type', 'Total_Vehicles',
#        'V1_Type', 'V1_Dir', 'V1_Driver_Age', 'V1_Lane_Num', 'V1_Action',
#        'V1_Driver_Factors', 'V1_Driver_Distracted', 'V1_Vehicle_Factors',
#        'V1_Most_Harmful_Event', 'V1_All_Events', 'V2_Type', 'V2_Dir',
#        'V2_Driver_Age', 'V2_Lane_Num', 'V2_Action', 'V2_Driver_Factors',
#        'V2_Driver_Distracted', 'V2_Vehicle_Factors', 'V2_Most_Harmful_Event',
#        'V2_All_Events', 'First_Harmful_Event', 'Nonmotorist_Factors',
#        'Factors_Roadway', 'Lighting', 'HWY_Factors', 'Agency',
#        'Accident_Rec_Num', 'Pedalcyclist', 'Pedestrian', 'Motorcyclist',
#        'AnimalType', 'CrashDateTimeUTC', 'GlobalID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237338 entries, 0 to 237337
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   X                      237338 non-null  float64
#  1   Y                      237338 non-null  float64
#  2   OBJECTID               237338 non-null  int64
#  3   Crash_Severity         237338 non-null  object
#  4   County                 237338 non-null  object
#  5   Crash_Date             237338 non-null  object
#  6   Crash_Year             237338 non-null  int64
#  7   Crash_Time             237338 non-null  object
#  8   Primary_Street         237338 non-null  object
#  9   Distance               165624 non-null  float64
#  10  Dir                    237338 non-null  object
#  11  Secondary_Street       237325 non-null  object
#  12  Weather                236307 non-null  object
#  13  Fatalities             1489 non-null    float64
# ...

# %%
df.count()
# Out:
# X                        237338
# Y                        237338
# OBJECTID                 237338
# Crash_Severity           237338
# County                   237338
# Crash_Date               237338
# Crash_Year               237338
# Crash_Time               237338
# Primary_Street           237338
# Distance                 165624
# Dir                      237338
# Secondary_Street         237325
# Weather                  236307
# Fatalities                 1489
# Injured                  100630
# Property_Damage_Only     135789
# Injury_Type              101276
# Crash_Type               236999
# Total_Vehicles           237338
# V1_Type                  227370
# V1_Dir                   207409
# V1_Driver_Age            183453
# V1_Lane_Num              163753
# V1_Action                236779
# V1_Driver_Factors        216065
# V1_Driver_Distracted      10155
# V1_Vehicle_Factors       215165
# V1_Most_Harmful_Event    116017
# V1_All_Events            123912
# ...

# %%
df.isnull().any()
# Out:
# X                        False
# Y                        False
# OBJECTID                 False
# Crash_Severity           False
# County                   False
# Crash_Date               False
# Crash_Year               False
# Crash_Time               False
# Primary_Street           False
# Distance                  True
# Dir                      False
# Secondary_Street          True
# Weather                   True
# Fatalities                True
# Injured                   True
# Property_Damage_Only      True
# Injury_Type               True
# Crash_Type                True
# Total_Vehicles           False
# V1_Type                   True
# V1_Dir                    True
# V1_Driver_Age             True
# V1_Lane_Num               True
# V1_Action                 True
# V1_Driver_Factors         True
# V1_Driver_Distracted      True
# V1_Vehicle_Factors        True
# V1_Most_Harmful_Event     True
# V1_All_Events             True
# V2_Type                   True
# ...

# %%
df.isnull().sum()
# Out:
# X                             0
# Y                             0
# OBJECTID                      0
# Crash_Severity                0
# County                        0
# Crash_Date                    0
# Crash_Year                    0
# Crash_Time                    0
# Primary_Street                0
# Distance                  71714
# Dir                           0
# Secondary_Street             13
# Weather                    1031
# Fatalities               235849
# Injured                  136708
# Property_Damage_Only     101549
# Injury_Type              136062
# Crash_Type                  339
# Total_Vehicles                0
# V1_Type                    9968
# V1_Dir                    29929
# V1_Driver_Age             53885
# V1_Lane_Num               73585
# V1_Action                   559
# V1_Driver_Factors         21273
# V1_Driver_Distracted     227183
# V1_Vehicle_Factors        22173
# V1_Most_Harmful_Event    121321
# V1_All_Events            113426
# ...

# %%
df.describe()
# Out:
#                    X              Y       OBJECTID     Crash_Year  \
# count  237338.000000  237338.000000  237338.000000  237338.000000
# mean     -116.118398      36.957822  782401.500000    2017.877841
# std         1.838500       1.492376   68513.723432       1.370374
# min      -120.005476      35.072088  663733.000000    2016.000000
# 25%      -115.335885      36.100901  723067.250000    2017.000000
# 50%      -115.183400      36.167954  782401.500000    2018.000000
# 75%      -115.120809      36.314060  841735.750000    2019.000000
# max      -114.044980      41.998326  901070.000000    2020.000000
#
#             Distance   Fatalities        Injured  Total_Vehicles  \
# count  165624.000000  1489.000000  100630.000000   237338.000000
# mean      442.469335     1.078576       1.536222        1.951681
# std      1315.668359     0.335817       0.903075        0.590174
# min         0.100000     1.000000       1.000000        0.000000
# ...

# %%
df.GlobalID.unique()
# Out:
# array(['{0087FD29-7934-4ECF-8F61-F2CB6A3C77F2}',
#        '{00FDF71D-5A6D-4715-B67D-064A9177A811}',
#        '{010D62A2-A007-45DF-A118-4C4F4257FBB4}', ...,
#        '{FDBCD936-FA23-4323-A5FA-8459D28BFE28}',
#        '{FDE7861D-219D-4A77-B116-4EFAE25A3A80}',
#        '{FF736BF8-3236-45C8-9B1E-8066FE11359F}'], dtype=object)
