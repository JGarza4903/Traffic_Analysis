# %%
import pandas as pd
import numpy as np

# %%
# Read in our dataset
df = pd.read_csv("CrashData_OpenData.csv")
df.head()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_14060\1458870752.py:2: DtypeWarning: Columns (22,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("CrashData_OpenData.csv")
#             X          Y  OBJECTID        Crash_Severity  County  \
# 0 -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY   CLARK
# 1 -119.673794  39.626433    663734  PROPERTY DAMAGE ONLY  WASHOE
# 2 -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY   CLARK
# 3 -119.633092  39.516952    663736  PROPERTY DAMAGE ONLY  WASHOE
# 4 -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY   CLARK
#
#                Crash_Date  Crash_Year   Crash_Time Primary_Street  Distance  \
# 0  2016/01/04 10:27:00+00        2016  10:27:00 AM          IR15N       1.0
# 1  2016/01/07 05:52:59+00        2016   5:53:00 AM      HUBBLE DR      20.0
# 2  2016/01/04 07:21:59+00        2016   7:22:00 AM          SR573      30.0
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Crash_Severity', 'County', 'Crash_Date',
#        'Crash_Year', 'Crash_Time', 'Primary_Street', 'Distance', 'Dir',
#        'Secondary_Street', 'Weather', 'Fatalities', 'Injured',
#        'Property_Damage_Only', 'Injury_Type', 'Crash_Type', 'Total_Vehicles',
#        'V1_Type', 'V1_Dir', 'V1_Driver_Age', 'V1_Lane_Num', 'V1_Action',
#        'V1_Driver_Factors', 'V1_Driver_Distracted', 'V1_Vehicle_Factors',
#        'V1_Most_Harmful_Event', 'V1_All_Events', 'V2_Type', 'V2_Dir',
#        'V2_Driver_Age', 'V2_Lane_Num', 'V2_Action', 'V2_Driver_Factors',
#        'V2_Driver_Distracted', 'V2_Vehicle_Factors', 'V2_Most_Harmful_Event',
#        'V2_All_Events', 'First_Harmful_Event', 'Nonmotorist_Factors',
#        'Factors_Roadway', 'Lighting', 'HWY_Factors', 'Agency',
#        'Accident_Rec_Num', 'Pedalcyclist', 'Pedestrian', 'Motorcyclist',
#        'AnimalType', 'CrashDateTimeUTC', 'GlobalID'],
#       dtype='object')

# %%
drop_df = df.drop(['OBJECTID','Property_Damage_Only','Agency','CrashDateTimeUTC','GlobalID'], axis=1)

# %%
drop_df.head(5)
# Out:
#             X          Y        Crash_Severity  County  \
# 0 -115.106709  36.236043  PROPERTY DAMAGE ONLY   CLARK
# 1 -119.673794  39.626433  PROPERTY DAMAGE ONLY  WASHOE
# 2 -115.101063  36.240200  PROPERTY DAMAGE ONLY   CLARK
# 3 -119.633092  39.516952  PROPERTY DAMAGE ONLY  WASHOE
# 4 -115.140570  36.192680  PROPERTY DAMAGE ONLY   CLARK
#
#                Crash_Date  Crash_Year   Crash_Time Primary_Street  Distance  \
# 0  2016/01/04 10:27:00+00        2016  10:27:00 AM          IR15N       1.0
# 1  2016/01/07 05:52:59+00        2016   5:53:00 AM      HUBBLE DR      20.0
# 2  2016/01/04 07:21:59+00        2016   7:22:00 AM          SR573      30.0
# 3  2016/01/06 00:20:00+00        2016  12:20:00 AM          IR80W    1320.0
# 4  2016/01/03 02:29:59+00        2016   2:30:00 AM          IR15S     200.0
#
#   Dir  ... First_Harmful_Event Nonmotorist_Factors  Factors_Roadway  \
# 0   S  ...                 NaN                 NaN              DRY
# ...

# %%
drop_df['Crash_Date'].value_counts()
# Out:
# 2018/02/22 15:53:00+00    11
# 2018/02/22 14:00:59+00     9
# 2017/02/23 09:00:00+00     8
# 2019/02/16 18:49:59+00     7
# 2016/11/03 04:28:59+00     6
#                           ..
# 2017/08/19 15:24:59+00     1
# 2017/08/16 08:06:59+00     1
# 2017/08/18 15:33:00+00     1
# 2017/08/21 13:05:00+00     1
# 2020/12/30 21:53:00+00     1
# Name: Crash_Date, Length: 219876, dtype: int64

# %%
drop_df.dtypes
# Out:
# X                        float64
# Y                        float64
# Crash_Severity            object
# County                    object
# Crash_Date                object
# Crash_Year                 int64
# Crash_Time                object
# Primary_Street            object
# Distance                 float64
# Dir                       object
# Secondary_Street          object
# Weather                   object
# Fatalities               float64
# Injured                  float64
# Injury_Type               object
# Crash_Type                object
# Total_Vehicles             int64
# V1_Type                   object
# V1_Dir                    object
# V1_Driver_Age            float64
# V1_Lane_Num               object
# V1_Action                 object
# V1_Driver_Factors         object
# V1_Driver_Distracted      object
# V1_Vehicle_Factors        object
# V1_Most_Harmful_Event     object
# V1_All_Events             object
# V2_Type                   object
# ...

# %%
drop_df.isna().sum()
# Out:
# X                             0
# Y                             0
# Crash_Severity                0
# County                        0
# Crash_Date                    0
# Crash_Year                    0
# Crash_Time                    0
# Primary_Street                0
# Distance                  71714
# Dir                           0
# Secondary_Street             13
# Weather                    1031
# Fatalities               235849
# Injured                  136708
# Injury_Type              136062
# Crash_Type                  339
# Total_Vehicles                0
# V1_Type                    9968
# V1_Dir                    29929
# V1_Driver_Age             53885
# V1_Lane_Num               73585
# V1_Action                   559
# V1_Driver_Factors         21273
# V1_Driver_Distracted     227183
# V1_Vehicle_Factors        22173
# V1_Most_Harmful_Event    121321
# V1_All_Events            113426
# V2_Type                   42171
# V2_Dir                    44732
# ...

# %%
clark_df = drop_df[drop_df['County'].str.contains('CL')]
print (clark_df)
# Out:
#                  X          Y        Crash_Severity County  \
# 0      -115.106709  36.236043  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.101063  36.240200  PROPERTY DAMAGE ONLY  CLARK
# 4      -115.140570  36.192680  PROPERTY DAMAGE ONLY  CLARK
# 5      -115.278964  36.136313           FATAL CRASH  CLARK
# 6      -115.162277  36.232014          INJURY CRASH  CLARK
# ...            ...        ...                   ...    ...
# 237333 -115.125575  36.086392          INJURY CRASH  CLARK
# 237334 -115.170558  36.123567  PROPERTY DAMAGE ONLY  CLARK
# 237335 -115.296210  36.114934          INJURY CRASH  CLARK
# 237336 -115.033041  36.056311  PROPERTY DAMAGE ONLY  CLARK
# 237337 -115.173247  36.125607          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N
# 2       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573
# ...

# %%
clark_df.head()
# Out:
#             X          Y        Crash_Severity County              Crash_Date  \
# 0 -115.106709  36.236043  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 10:27:00+00
# 2 -115.101063  36.240200  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 07:21:59+00
# 4 -115.140570  36.192680  PROPERTY DAMAGE ONLY  CLARK  2016/01/03 02:29:59+00
# 5 -115.278964  36.136313           FATAL CRASH  CLARK  2016/01/03 00:00:00+00
# 6 -115.162277  36.232014          INJURY CRASH  CLARK  2016/01/06 06:01:59+00
#
#    Crash_Year   Crash_Time  Primary_Street  Distance Dir  ...  \
# 0        2016  10:27:00 AM           IR15N       1.0   S  ...
# 2        2016   7:22:00 AM           SR573      30.0   W  ...
# 4        2016   2:30:00 AM           IR15S     200.0   S  ...
# 5        2016   9:22:00 PM    S DURANGO DR     147.0   S  ...
# 6        2016   6:02:00 AM  W ALEXANDER RD     100.0   W  ...
#
#   First_Harmful_Event            Nonmotorist_Factors  Factors_Roadway  \
# ...

# %%
clark_df.shape
# Out:
# (178458, 47)

# %%
clark_df['County'].value_counts()
# Out:
# CLARK    178458
# Name: County, dtype: int64

# %%
clark_df.isna().sum()
# Out:
# X                             0
# Y                             0
# Crash_Severity                0
# County                        0
# Crash_Date                    0
# Crash_Year                    0
# Crash_Time                    0
# Primary_Street                0
# Distance                  51609
# Dir                           0
# Secondary_Street              1
# Weather                     553
# Fatalities               177498
# Injured                   97385
# Injury_Type               96955
# Crash_Type                  166
# Total_Vehicles                0
# V1_Type                    7687
# V1_Dir                    21503
# V1_Driver_Age             41376
# V1_Lane_Num               54219
# V1_Action                   387
# V1_Driver_Factors         15428
# V1_Driver_Distracted     171201
# V1_Vehicle_Factors        14986
# V1_Most_Harmful_Event     90618
# V1_All_Events             89686
# V2_Type                   23791
# V2_Dir                    25331
# ...

# %%
clark_df.head()
# Out:
#             X          Y        Crash_Severity County              Crash_Date  \
# 0 -115.106709  36.236043  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 10:27:00+00
# 2 -115.101063  36.240200  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 07:21:59+00
# 4 -115.140570  36.192680  PROPERTY DAMAGE ONLY  CLARK  2016/01/03 02:29:59+00
# 5 -115.278964  36.136313           FATAL CRASH  CLARK  2016/01/03 00:00:00+00
# 6 -115.162277  36.232014          INJURY CRASH  CLARK  2016/01/06 06:01:59+00
#
#    Crash_Year   Crash_Time  Primary_Street  Distance Dir  ...  \
# 0        2016  10:27:00 AM           IR15N       1.0   S  ...
# 2        2016   7:22:00 AM           SR573      30.0   W  ...
# 4        2016   2:30:00 AM           IR15S     200.0   S  ...
# 5        2016   9:22:00 PM    S DURANGO DR     147.0   S  ...
# 6        2016   6:02:00 AM  W ALEXANDER RD     100.0   W  ...
#
#   First_Harmful_Event            Nonmotorist_Factors  Factors_Roadway  \
# ...

# %%
clark_df.First_Harmful_Event.unique()
# Out:
# array([nan, 'RAN OFF ROAD RIGHT', 'MOTOR VEHICLE IN TRANSPORT',
#        'CROSS MEDIAN/CENTERLINE', 'PARKED MOTOR VEHICLE', 'PEDAL CYCLE',
#        'OVERTURN/ROLLOVER', 'PEDESTRIAN', 'SLOW/STOPPED VEHICLE',
#        'UTILITY POLE', 'CURB', 'RAN OFF ROAD LEFT', 'OTHER NON-COLLISION',
#        'CONCRETE TRAFFIC BARRIER',
#        'OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)', 'MEDIAN BARRIER',
#        'IMMERSION', 'OTHER MOVABLE OBJECT', 'UNKNOWN FIXED OBJECT',
#        'UNKNOWN NON-COLLISION', 'CARGO/EQUIPMENT LOSS OR SHIFT',
#        'OTHER ANIMAL', 'LIGHT/LUMINARY SUPPORT',
#        'WORK ZONE MAINTENANCE EQUIPMENT', 'GUARDRAIL FACE',
#        'OTHER POST, POLE OR SUPPORT', 'SEPARATION OF UNITS', 'FENCE/WALL',
#        'TRAFFIC SIGNAL SUPPORT', 'PEDAL CYCLIST', 'DITCH',
#        'EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)',
#        'THROWN OR FALLING OBJECT', 'TREE/SHRUB', 'JACKKNIFE',
#        'MECHANICAL DEFECTS', 'UNKNOWN MOVABLE OBJECT', 'CROSS MEDIAN',
# ...

# %%
    clark_df['Pedalcyclist'].fillna('Unknown', inplace=True)
    clark_df['Pedestrian'].fillna('Unknown', inplace=True)
    clark_df['Motorcyclist'].fillna('Unknown', inplace=True)
    clark_df['AnimalType'].fillna('Unknown', inplace=True)
    clark_df['Nonmotorist_Factors'].fillna('Unknown', inplace=True)
    clark_df['First_Harmful_Event'].fillna('Unknown', inplace=True)
    clark_df['V1_Vehicle_Factors'].fillna('Unknown', inplace=True)
    clark_df['V1_Type'].fillna('Unknown', inplace=True)
    clark_df['V1_Driver_Factors'].fillna('Unknown', inplace=True)
    clark_df['V2_Type'].fillna('Unknown', inplace=True)
    clark_df['V2_Action'].fillna('Unknown', inplace=True)
    clark_df['V2_Driver_Factors'].fillna('Unknown', inplace=True)
    clark_df['Factors_Roadway'].fillna('Unknown', inplace=True)
    clark_df['Lighting'].fillna('Unknown', inplace=True)
    clark_df['HWY_Factors'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_14060\557977518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clark_df['Pedalcyclist'].fillna('Unknown', inplace=True)
# C:\Users\Home\AppData\Local\Temp\ipykernel_14060\557977518.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clark_df['Pedestrian'].fillna('Unknown', inplace=True)
# C:\Users\Home\AppData\Local\Temp\ipykernel_14060\557977518.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
clark_df.head()
# Out:
#             X          Y        Crash_Severity County              Crash_Date  \
# 0 -115.106709  36.236043  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 10:27:00+00
# 2 -115.101063  36.240200  PROPERTY DAMAGE ONLY  CLARK  2016/01/04 07:21:59+00
# 4 -115.140570  36.192680  PROPERTY DAMAGE ONLY  CLARK  2016/01/03 02:29:59+00
# 5 -115.278964  36.136313           FATAL CRASH  CLARK  2016/01/03 00:00:00+00
# 6 -115.162277  36.232014          INJURY CRASH  CLARK  2016/01/06 06:01:59+00
#
#    Crash_Year   Crash_Time  Primary_Street  Distance Dir  ...  \
# 0        2016  10:27:00 AM           IR15N       1.0   S  ...
# 2        2016   7:22:00 AM           SR573      30.0   W  ...
# 4        2016   2:30:00 AM           IR15S     200.0   S  ...
# 5        2016   9:22:00 PM    S DURANGO DR     147.0   S  ...
# 6        2016   6:02:00 AM  W ALEXANDER RD     100.0   W  ...
#
#   First_Harmful_Event            Nonmotorist_Factors  Factors_Roadway  \
# ...

# %%
clark_df.isna().sum()
# Out:
# X                             0
# Y                             0
# Crash_Severity                0
# County                        0
# Crash_Date                    0
# Crash_Year                    0
# Crash_Time                    0
# Primary_Street                0
# Distance                  51609
# Dir                           0
# Secondary_Street              1
# Weather                     553
# Fatalities               177498
# Injured                   97385
# Injury_Type               96955
# Crash_Type                  166
# Total_Vehicles                0
# V1_Type                       0
# V1_Dir                    21503
# V1_Driver_Age             41376
# V1_Lane_Num               54219
# V1_Action                   387
# V1_Driver_Factors             0
# V1_Driver_Distracted     171201
# V1_Vehicle_Factors            0
# V1_Most_Harmful_Event     90618
# V1_All_Events             89686
# V2_Type                       0
# V2_Dir                    25331
# ...
