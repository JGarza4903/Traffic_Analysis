# %%
import pandas as pd
import numpy as np

# %%
# Read in our dataset
df = pd.read_csv("Traffic_Crashes.csv")
df.head()
# Out:
# C:\Users\Home\AppData\Local\Temp\ipykernel_3604\353040497.py:2: DtypeWarning: Columns (18,19,28,29,42,43,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Traffic_Crashes.csv")
#              Crash_Seve County              Crash_Date  Crash_Year  \
# 0  PROPERTY DAMAGE ONLY  CLARK  2015/05/12 00:00:00+00        2015
# 1          INJURY CRASH  CLARK  2015/01/07 00:00:00+00        2015
# 2  PROPERTY DAMAGE ONLY  CLARK  2015/01/07 00:00:00+00        2015
# 3          INJURY CRASH  CLARK  2015/05/01 00:00:00+00        2015
# 4          INJURY CRASH  CLARK  2015/06/24 00:00:00+00        2015
#
#                Crash_Time          Primary_St  Distance  Dir      Secondary_  \
# 0  2023/01/12 15:52:00+00         STEWART AVE      60.0    E  LAS VEGAS BLVD
# 1  2023/01/12 12:18:00+00  MARTIN L KING BLVD     300.0    N      BALZAR AVE
# 2  2023/01/12 08:12:00+00            CRAIG RD      48.0    E    N BUFFALO DR
# ...

# %%
# Drop columns
to_drop = [
    'ACRES',
    'Agency',
    'AREA',
    'CNTY_IS',
    'County',
    'CrashDateT',
    'SHADE',
    'SQ_MILES',
    'Property_D',
    'WARD',
    'PERIMETER']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#              Crash_Seve              Crash_Date  Crash_Year  \
# 0  PROPERTY DAMAGE ONLY  2015/05/12 00:00:00+00        2015
# 1          INJURY CRASH  2015/01/07 00:00:00+00        2015
# 2  PROPERTY DAMAGE ONLY  2015/01/07 00:00:00+00        2015
# 3          INJURY CRASH  2015/05/01 00:00:00+00        2015
# 4          INJURY CRASH  2015/06/24 00:00:00+00        2015
#
#                Crash_Time          Primary_St  Distance  Dir      Secondary_  \
# 0  2023/01/12 15:52:00+00         STEWART AVE      60.0    E  LAS VEGAS BLVD
# 1  2023/01/12 12:18:00+00  MARTIN L KING BLVD     300.0    N      BALZAR AVE
# 2  2023/01/12 08:12:00+00            CRAIG RD      48.0    E    N BUFFALO DR
# 3  2023/01/12 23:21:00+00         STEWART AVE       0.0  NaN   BEECHGATE AVE
# 4  2023/01/12 20:55:00+00               SR159       0.0  NaN    S DURANGO DR
#
#   Weather  Fatalities  ...  Nonmotoris Factors_Ro                    Lighting  \
# ...

# %%
df.isnull()
# Out:
#        Crash_Seve  Crash_Date  Crash_Year  Crash_Time  Primary_St  Distance  \
# 0           False       False       False       False       False     False
# 1           False       False       False       False       False     False
# 2           False       False       False       False       False     False
# 3           False       False       False       False       False     False
# 4           False       False       False       False       False     False
# ...           ...         ...         ...         ...         ...       ...
# 70883       False       False       False       False       False     False
# 70884       False       False       False       False       False     False
# 70885       False       False       False       False       False     False
# 70886       False       False       False       False       False     False
# 70887       False       False       False       False       False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Crash_Seve        0
# Crash_Date        0
# Crash_Year        0
# Crash_Time        0
# Primary_St        0
# Distance          0
# Dir            8243
# Secondary_       18
# Weather         161
# Fatalities    20130
# Injured       10546
# Injury_Typ    33252
# Crash_Type      205
# Total_Vehi        0
# V1_Type        1638
# V1_Dir         7365
# V1_Driver_     9768
# V1_Lane_Nu    25728
# V1_Action       181
# V1_Driver1    13590
# V1_Drive_1    68922
# V1_Vehicle    15183
# V1_Most_Ha    49092
# V1_All_Eve    31091
# V2_Type       10231
# V2_Dir        18658
# V2_Driver_    10059
# V2_Lane_Nu    29872
# V2_Action     10125
# V2_Driver1    20218
# V2_Drive_1    70864
# V2_Vehicle    64452
# V2_Most_Ha    51290
# V2_All_Eve    57119
# First_Harm    49109
# Nonmotoris    69169
# Factors_Ro     5690
# Lighting       5525
# HWY_Factor     5738
# Accident_R        0
# Pedalcycli    70525
# Pedestrian    70101
# Motorcycli    70123
# AnimalType    70857
# ObjectId          0
# ...

# %%
df.isnull().mean()
# Out:
# Crash_Seve    0.000000
# Crash_Date    0.000000
# Crash_Year    0.000000
# Crash_Time    0.000000
# Primary_St    0.000000
# Distance      0.000000
# Dir           0.116282
# Secondary_    0.000254
# Weather       0.002271
# Fatalities    0.283969
# Injured       0.148770
# Injury_Typ    0.469078
# Crash_Type    0.002892
# Total_Vehi    0.000000
# V1_Type       0.023107
# V1_Dir        0.103896
# V1_Driver_    0.137795
# V1_Lane_Nu    0.362939
# V1_Action     0.002553
# V1_Driver1    0.191711
# V1_Drive_1    0.972266
# V1_Vehicle    0.214183
# V1_Most_Ha    0.692529
# V1_All_Eve    0.438593
# V2_Type       0.144326
# V2_Dir        0.263204
# V2_Driver_    0.141900
# V2_Lane_Nu    0.421397
# V2_Action     0.142831
# V2_Driver1    0.285210
# V2_Drive_1    0.999661
# V2_Vehicle    0.909209
# V2_Most_Ha    0.723536
# V2_All_Eve    0.805764
# First_Harm    0.692769
# Nonmotoris    0.975750
# Factors_Ro    0.080267
# Lighting      0.077940
# HWY_Factor    0.080945
# Accident_R    0.000000
# ...

# %%
df = df.fillna("Unknown")

# %%
df.head()
# Out:
#              Crash_Seve              Crash_Date  Crash_Year  \
# 0  PROPERTY DAMAGE ONLY  2015/05/12 00:00:00+00        2015
# 1          INJURY CRASH  2015/01/07 00:00:00+00        2015
# 2  PROPERTY DAMAGE ONLY  2015/01/07 00:00:00+00        2015
# 3          INJURY CRASH  2015/05/01 00:00:00+00        2015
# 4          INJURY CRASH  2015/06/24 00:00:00+00        2015
#
#                Crash_Time          Primary_St  Distance      Dir  \
# 0  2023/01/12 15:52:00+00         STEWART AVE      60.0        E
# 1  2023/01/12 12:18:00+00  MARTIN L KING BLVD     300.0        N
# 2  2023/01/12 08:12:00+00            CRAIG RD      48.0        E
# 3  2023/01/12 23:21:00+00         STEWART AVE       0.0  Unknown
# 4  2023/01/12 20:55:00+00               SR159       0.0  Unknown
#
#        Secondary_ Weather  Fatalities  ...  Nonmotoris Factors_Ro  \
# 0  LAS VEGAS BLVD   CLEAR         0.0  ...     Unknown        DRY
# 1      BALZAR AVE   CLEAR         0.0  ...     Unknown        DRY
# ...

# %%
df.count()
# Out:
# Crash_Seve    70888
# Crash_Date    70888
# Crash_Year    70888
# Crash_Time    70888
# Primary_St    70888
# Distance      70888
# Dir           70888
# Secondary_    70888
# Weather       70888
# Fatalities    70888
# Injured       70888
# Injury_Typ    70888
# Crash_Type    70888
# Total_Vehi    70888
# V1_Type       70888
# V1_Dir        70888
# V1_Driver_    70888
# V1_Lane_Nu    70888
# V1_Action     70888
# V1_Driver1    70888
# V1_Drive_1    70888
# V1_Vehicle    70888
# V1_Most_Ha    70888
# V1_All_Eve    70888
# V2_Type       70888
# V2_Dir        70888
# V2_Driver_    70888
# V2_Lane_Nu    70888
# V2_Action     70888
# V2_Driver1    70888
# V2_Drive_1    70888
# V2_Vehicle    70888
# V2_Most_Ha    70888
# V2_All_Eve    70888
# First_Harm    70888
# Nonmotoris    70888
# Factors_Ro    70888
# Lighting      70888
# HWY_Factor    70888
# Accident_R    70888
# Pedalcycli    70888
# Pedestrian    70888
# Motorcycli    70888
# AnimalType    70888
# ObjectId      70888
# ...
