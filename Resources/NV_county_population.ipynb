# %%
import pandas as pd

# %%
df = pd.read_csv('co-est2020.csv', encoding = "ISO-8859-1")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  POPESTIMATE2012  \
# 0       4779736            4780118          4785514  ...          4816632
# 1         54571              54582            54761  ...            54970
# 2        182265             182263           183121  ...           190203
# 3         27457              27454            27325  ...            27172
# 4         22915              22904            22858  ...            22657
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# ...

# %%
nevada_df = df[df.STNAME == "Nevada"]
nevada_df.head()
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY  STNAME           CTYNAME  \
# 1776      40       4         8     32       0  Nevada            Nevada
# 1777      50       4         8     32       1  Nevada  Churchill County
# 1778      50       4         8     32       3  Nevada      Clark County
# 1779      50       4         8     32       5  Nevada    Douglas County
# 1780      50       4         8     32       7  Nevada       Elko County
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  POPESTIMATE2012  \
# 1776       2700551            2700683          2702483  ...          2744670
# 1777         24877              24875            24816  ...            24267
# 1778       1951269            1951278          1952640  ...          1989644
# 1779         46997              47000            47037  ...            46930
# 1780         48818              48942            49093  ...            50998
#
# ...

# %%
nevada_df.columns

county_df = nevada_df.drop(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY','STNAME'], axis = 1)
# Out:
#                CTYNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 1776            Nevada       2700551            2700683          2702483
# 1777  Churchill County         24877              24875            24816
# 1778      Clark County       1951269            1951278          1952640
# 1779    Douglas County         46997              47000            47037
# 1780       Elko County         48818              48942            49093
#
#       POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 1776          2713114          2744670          2776956          2818935
# 1777            24607            24267            23956            23864
# 1778          1962162          1989644          2017798          2053929
# 1779            46982            46930            46956            47406
# 1780            49463            50998            52378            52616
#
#       POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# ...

# %%
county_df.drop(county_df.columns[[1,2,3,4,5,6,7,]], axis=1, inplace=True)

# %%
county_df.head()
# Out:
#                CTYNAME  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 1776            Nevada          2868531          2919555          2972097
# 1777  Churchill County            24006            23957            24088
# 1778      Clark County          2097832          2140240          2183273
# 1779    Douglas County            47422            47805            48014
# 1780       Elko County            51756            52022            52307
#
#       POPESTIMATE2018  POPESTIMATE2019  POPESTIMATE042020  POPESTIMATE2020
# 1776          3030725          3090771            3128500          3138259
# 1777            24574            25048              25334            25363
# 1778          2228970          2275884            2307540          2315963
# 1779            48527            48998              49135            49088
# 1780            52470            52880              52997            53006

# %%
county_df.to_csv('NV_county_population.csv')
