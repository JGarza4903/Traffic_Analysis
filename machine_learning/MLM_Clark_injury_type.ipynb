# %% [markdown]
# # Clark County Only, Injury Type as Target

# %% [markdown]
# ## Imports and Setup

# %%
# Initial imports
import pandas as pd
import numpy as np
import psycopg2 
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Load in password
from secret import secret, database, username, host

# Establish connection to database
conn = psycopg2.connect(
    host = host,
    database = database,
    user =username,
    password = secret
)

# %%
# Load the data
query = 'SELECT * FROM clark_co_traffic'
traffic_df = pd.read_sql_query(query, conn)
# Out:
# /var/folders/f3/5zcd9_1j7d3546ws7g9t5fw00000gp/T/ipykernel_6132/3027837082.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   traffic_df = pd.read_sql_query(query, conn)

# %% [markdown]
# ## Preprocess Data

# %%
# Filter for Clark County
traffic_df = traffic_df.loc[traffic_df['county'] == 'CLARK']
traffic_df.drop(columns = ['county'], inplace = True)

# %%
# Drop unnecessary columns
traffic_df.drop(columns = ['objectid','crash_severity','accident_rec_num','primary_street', 'secondary_street', 'fatalities', 'injured' ], inplace = True)

# %%
# Move PDO values from property_damage_only column info to injury_type column
traffic_df['injury_type'] = np.where(traffic_df['property_damage_only'] == 'PDO', traffic_df['property_damage_only'], traffic_df['injury_type'])

# %%
# Drop property damage only column
traffic_df.drop(columns = ['property_damage_only'], inplace = True)

# %%
# Split single column with multiple data points into separate columns
traffic_df[['v1_driver_factors_1', 'v1_driver_factors_2','v1_driver_factors_3', 'v1_driver_factors_4']] = traffic_df['v1_driver_factors'].str.split(':', expand=True)

traffic_df[['v1_vehicle_factors_1', 'v1_vehicle_factors_2','v1_vehicle_factors_3', 'v1_vehicle_factors_4', 'v1_vehicle_factors_5']] = traffic_df['v1_vehicle_factors'].str.split(':', expand=True)

traffic_df[['v1_all_events_1', 'v1_all_events_2','v1_all_events_3', 'v1_all_events_4', 'v1_all_events_5']] = traffic_df['v1_all_events'].str.split(':', expand=True)

traffic_df[['v2_driver_factors_1', 'v2_driver_factors_2']] = traffic_df['v2_driver_factors'].str.split(':', expand=True)

traffic_df[['v2_vehicle_factors_1', 'v2_vehicle_factors_2','v2_vehicle_factors_3', 'v2_vehicle_factors_4', 'v2_vehicle_factors_5']] = traffic_df['v2_vehicle_factors'].str.split(':', expand=True)

traffic_df[['v2_all_events_1', 'v2_all_events_2','v2_all_events_3', 'v2_all_events_4', 'v2_all_events_5']] = traffic_df['v1_all_events'].str.split(':', expand=True)

traffic_df[['nonmotorist_factors_1', 'nonmotorist_factors_2','nonmotorist_factors_3', 'nonmotorist_factors_4', 'nonmotorist_factors_5']] = traffic_df['nonmotorist_factors'].str.split(':', expand=True)

# traffic_df[['factors_roadway_1', 'factors_roadway_2','factors_roadways_3']] = traffic_df['factors_roadway'].str.split(':', expand=True)

traffic_df[['hwy_factors_1', 'hwy_factors_2','hwy_factors_3', 'hwy_factors_4']] = traffic_df['hwy_factors'].str.split(':', expand=True)

traffic_df.drop(columns = ['v1_driver_factors','v1_vehicle_factors','v1_all_events','v2_driver_factors','v2_vehicle_factors', 'v2_all_events', 'nonmotorist_factors', 'hwy_factors',], inplace = True)

# %%
traffic_df['injury_type'].value_counts()
# Out:
# PDO    91631
# C      57266
# B      17300
# A       2707
# K        788
# U        128
# Name: injury_type, dtype: int64

# %%
# Change target values to numeric
# Values are based on Nevada Traffic Records Coordinating Committee Data Dictionary,
# https://zerofatalitiesnv.com/app/uploads/2021/04/2021-01-NV-TRCC-Data-Dictionary.pdf
injury_num = {
    'K': 5,
    'A': 4,
    'B': 3,
    'C': 2,
    'PDO': 1,
    'U': 0,      
}

traffic_df['injury_type'] = traffic_df['injury_type'].apply(lambda x: injury_num[x])

traffic_df['injury_type'].value_counts()
# Out:
# 2    91631
# 3    57266
# 4    17300
# 5     2707
# 6      788
# 1      128
# Name: injury_type, dtype: int64

# %%
# Extract datetime values into separate columns
traffic_df['crash_month'] = pd.DatetimeIndex(traffic_df['crash_date']).month
traffic_df['crash_day'] = pd.DatetimeIndex(traffic_df['crash_date']).day
traffic_df['crash_day_of_week'] = pd.DatetimeIndex(traffic_df['crash_date']).dayofweek
traffic_df['crash_hour'] = pd.DatetimeIndex(traffic_df['crash_time']).hour

# %%
# Drop original datetime columns
traffic_df.drop(columns = ['crash_date', 'crash_time'], inplace = True)

# %%
traffic_df.dtypes
# Out:
# x                    float64
# y                    float64
# crash_year             int64
# weather               object
# injury_type            int64
#                       ...
# hwy_factors_4         object
# crash_month            int64
# crash_day              int64
# crash_day_of_week      int64
# crash_hour             int64
# Length: 62, dtype: object

# %%
# Get names of all columns with dtypes of "object"
sel_cols = list(traffic_df.select_dtypes(include='object'))

# %%
# Preprocessing to convert all strings to numeric values
traffic_df_encoded = pd.get_dummies(traffic_df, columns = sel_cols)
traffic_df_encoded.head()
# Out:
#             x          y  crash_year  injury_type  total_vehicles  \
# 0 -115.106709  36.236043        2016            2               2
# 2 -115.101063  36.240200        2016            2               2
# 4 -115.140570  36.192680        2016            2               1
# 5 -115.278964  36.136313        2016            6               1
# 6 -115.162277  36.232014        2016            3               1
#
#    v1_driver_age  v2_driver_age  crash_month  crash_day  crash_day_of_week  \
# 0             35             41            1          4                  0
# 2             31             53            1          4                  0
# 4             56             41            1          3                  6
# 5             35             41            1          3                  6
# 6             43             41            1          6                  2
#
#    ...  hwy_factors_3_ OTHER ENVIRONMENTAL  hwy_factors_3_ OTHER HIGHWAY  \
# 0  ...                                   0                             0
# 2  ...                                   0                             0
# 4  ...                                   0                             0
# 5  ...                                   0                             0
# 6  ...                                   0                             0
#
#    hwy_factors_3_ ROAD OBSTRUCTION  hwy_factors_3_ RUTS, HOLES, BUMPS  \
# 0                                0                                  0
# 2                                0                                  0
# 4                                0                                  0
# 5                                0                                  0
# 6                                0                                  0
#
#    hwy_factors_3_ SHOULDERS  hwy_factors_3_ VISUAL OBSTRUCTION(S)  \
# 0                         0                                     0
# 2                         0                                     0
# 4                         0                                     0
# 5                         0                                     0
# 6                         0                                     0
#
#    hwy_factors_3_ WEATHER  hwy_factors_3_ WET, ICY, SNOW, SLUSH  \
# 0                       0                                     0
# 2                       0                                     0
# 4                       0                                     0
# 5                       0                                     0
# 6                       0                                     0
#
#    hwy_factors_3_ WORK ZONE (CONST. MAINT. UTILITY)  \
# 0                                                 0
# 2                                                 0
# 4                                                 0
# 5                                                 0
# 6                                                 0
#
#    hwy_factors_4_ WET, ICY, SNOW, SLUSH
# 0                                     0
# 2                                     0
# 4                                     0
# 5                                     0
# 6                                     0
#
# [5 rows x 1232 columns]

# %% [markdown]
# ## Model for Clark County with Injury Type as Target and All Other Columns as Features

# %%
# Separate data into features and target
y = traffic_df_encoded['injury_type'].values
X = traffic_df_encoded.drop(columns = 'injury_type')

# %%
# Split dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y)
X_train.shape
# Out:
# (127365, 1231)

# %%
# Scale the model
scaler = StandardScaler() 

# Fit the scaler with the training data
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create and fit the Random Forest model
rf_model = RandomForestClassifier(n_estimators = 128)
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Create predictions
predictions = rf_model.predict(X_test_scaled)
results = pd.DataFrame({
    "Prediction": predictions,
    "Actual": y_test
}).reset_index(drop = True)
results.head()
# Out:
#    Prediction  Actual
# 0           2       2
# 1           3       3
# 2           3       2
# 3           2       3
# 4           3       3

# %%
# Assess accuracy score
accuracy = accuracy_score(y_test, predictions)
accuracy
# Out:
# 0.6460958662112826

# %%
# Generate confusion matrix and dataframe
cm = confusion_matrix(y_test, predictions)

index_values = ['Actual: Unknown', 
                'Actual: Property Damage Only', 
                'Actual: Possible Injury', 
                'Actual: Suspected Minor Injury', 
                'Actual: Suspected Serious Injury', 
                'Actual: Fatal Injury']

column_values = ['Predicted: Unknown', 
                'Predicted: Property Damage Only', 
                'Predicted: Possible Injury', 
                'Predicted: Suspected Minor Injury', 
                'Predicted: Suspected Serious Injury', 
                'Predicted: Fatal Injury']

cm_df = pd.DataFrame(cm, index = index_values, columns = column_values)
cm_df
# Out:
#                                   Predicted: Unknown  \
# Actual: Unknown                                    0
# Actual: Property Damage Only                       0
# Actual: Possible Injury                            0
# Actual: Suspected Minor Injury                     0
# Actual: Suspected Serious Injury                   0
# Actual: Fatal Injury                               0
#
#                                   Predicted: Property Damage Only  \
# Actual: Unknown                                                13
# Actual: Property Damage Only                                18501
# Actual: Possible Injury                                      5484
# Actual: Suspected Minor Injury                               1306
# Actual: Suspected Serious Injury                              169
# Actual: Fatal Injury                                           65
#
#                                   Predicted: Possible Injury  \
# Actual: Unknown                                            8
# Actual: Property Damage Only                            4328
# Actual: Possible Injury                                 8468
# Actual: Suspected Minor Injury                          2582
# Actual: Suspected Serious Injury                         305
# Actual: Fatal Injury                                      43
#
#                                   Predicted: Suspected Minor Injury  \
# Actual: Unknown                                                  11
# Actual: Property Damage Only                                     77
# Actual: Possible Injury                                         351
# Actual: Suspected Minor Injury                                  414
# Actual: Suspected Serious Injury                                169
# Actual: Fatal Injury                                             59
#
#                                   Predicted: Suspected Serious Injury  \
# Actual: Unknown                                                     0
# Actual: Property Damage Only                                        2
# Actual: Possible Injury                                            11
# Actual: Suspected Minor Injury                                     20
# Actual: Suspected Serious Injury                                   27
# Actual: Fatal Injury                                               10
#
#                                   Predicted: Fatal Injury
# Actual: Unknown                                         0
# Actual: Property Damage Only                            0
# Actual: Possible Injury                                 2
# Actual: Suspected Minor Injury                          3
# Actual: Suspected Serious Injury                        7
# Actual: Fatal Injury                                   20

# %% [markdown]
# ## Results for Clark County with Injury Type as Target and All Other Columns as Features

# %%
# Display results
print('Confusion Matrix')
display(cm_df)
print(f'\nAccuracy Score: {accuracy}\n')
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#                                   Predicted: Unknown  \
# Actual: Unknown                                    0
# Actual: Property Damage Only                       0
# Actual: Possible Injury                            0
# Actual: Suspected Minor Injury                     0
# Actual: Suspected Serious Injury                   0
# Actual: Fatal Injury                               0
#
#                                   Predicted: Property Damage Only  \
# Actual: Unknown                                                13
# Actual: Property Damage Only                                18501
# Actual: Possible Injury                                      5484
# Actual: Suspected Minor Injury                               1306
# Actual: Suspected Serious Injury                              169
# Actual: Fatal Injury                                           65
#
#                                   Predicted: Possible Injury  \
# Actual: Unknown                                            8
# Actual: Property Damage Only                            4328
# Actual: Possible Injury                                 8468
# Actual: Suspected Minor Injury                          2582
# Actual: Suspected Serious Injury                         305
# Actual: Fatal Injury                                      43
#
#                                   Predicted: Suspected Minor Injury  \
# Actual: Unknown                                                  11
# Actual: Property Damage Only                                     77
# Actual: Possible Injury                                         351
# Actual: Suspected Minor Injury                                  414
# Actual: Suspected Serious Injury                                169
# Actual: Fatal Injury                                             59
#
#                                   Predicted: Suspected Serious Injury  \
# Actual: Unknown                                                     0
# Actual: Property Damage Only                                        2
# Actual: Possible Injury                                            11
# Actual: Suspected Minor Injury                                     20
# Actual: Suspected Serious Injury                                   27
# Actual: Fatal Injury                                               10
#
#                                   Predicted: Fatal Injury
# Actual: Unknown                                         0
# Actual: Property Damage Only                            0
# Actual: Possible Injury                                 2
# Actual: Suspected Minor Injury                          3
# Actual: Suspected Serious Injury                        7
# Actual: Fatal Injury                                   20
# Accuracy Score: 0.6460958662112826
#
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        32
#            2       0.72      0.81      0.76     22908
#            3       0.54      0.59      0.56     14316
#            4       0.38      0.10      0.15      4325
#            5       0.39      0.04      0.07       677
#            6       0.62      0.10      0.17       197
#
#     accuracy                           0.65     42455
#    macro avg       0.44      0.27      0.29     42455
# weighted avg       0.62      0.65      0.62     42455
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/miniconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Importances for Clark County with Injury Type as Target and All Other Columns as Features

# %%
# Calculate importance of features
importances = rf_model.feature_importances_
important = sorted(zip(importances, X.columns), reverse = True)
important
# Out:
# [(0.05457054485297779, 'y'),
#  (0.05450121327270793, 'v1_driver_age'),
#  (0.05401595354301524, 'x'),
#  (0.04795770780992282, 'v2_driver_age'),
#  (0.046772685196051454, 'crash_day'),
#  (0.0435151128106328, 'crash_hour'),
#  (0.039984688468446224, 'crash_month'),
#  (0.03534417703322784, 'crash_day_of_week'),
#  (0.02302574129124955, 'crash_year'),
#  (0.02284611815144245, 'factors_roadway_UNKNOWN'),
#  (0.019163240402188253, 'lighting_UNKNOWN'),
#  (0.01774361999522802, 'factors_roadway_DRY'),
#  (0.013957344740033913, 'hwy_factors_1_UNKNOWN'),
#  (0.01324555690394835, 'hwy_factors_1_NONE'),
#  (0.013202447105025474, 'lighting_DAYLIGHT'),
#  (0.012621915961743438, 'total_vehicles'),
#  (0.012068326621819512, 'v1_type_SEDAN, 4 DOOR'),
#  (0.00915164593678924, 'v2_type_SEDAN, 4 DOOR'),
#  (0.008997451313453671, 'v1_type_CARRY-ALL'),
#  (0.008865194720779254, 'v1_vehicle_factors_1_FAILED TO YIELD RIGHT OF WAY'),
#  (0.008590071907621592, 'v1_action_GOING STRAIGHT'),
#  (0.00821069859834884, 'v1_driver_factors_1_APPARENTLY NORMAL'),
#  (0.007960090878910057, 'crash_type_ANGLE'),
#  (0.007719378783092077, 'v1_type_PICKUP'),
#  (0.0076412045757433, 'v2_type_CARRY-ALL'),
#  (0.0073107445542895545, 'lighting_DARK - CONTINUOUS LIGHTING '),
#  (0.007183189911654514, 'crash_type_SIDESWIPE, OVERTAKING'),
#  (0.007079038854133896, 'weather_CLEAR'),
#  (0.006525182614338806, 'v2_action_GOING STRAIGHT'),
#  (0.006433633288986426, 'weather_CLOUDY'),
#  (0.006104306669026445, 'v2_type_PICKUP'),
#  (0.0059714414546538285, 'v1_action_TURNING LEFT'),
#  (0.0056364027372037455, 'lighting_DARK - SPOT LIGHTING'),
#  (0.005511466786770121, 'v1_driver_factors_1_UNKNOWN'),
#  (0.005353948229424307, 'v1_vehicle_factors_1_UNKNOWN'),
#  (0.005105375822673884, 'crash_type_REAR-END'),
#  (0.004684055195049496, 'v1_type_HATCHBACK, 4 DOOR'),
#  (0.004594061945888242,
#   'v1_vehicle_factors_1_DISREGARDED TRAFFIC SIGNS, SIGNALS, ROAD MARKINGS'),
#  (0.004589622889091225, 'v1_action_CHANGING LANES'),
#  (0.004537324177371124,
#   'v1_vehicle_factors_1_DRIVING TOO FAST FOR CONDITIONS'),
#  (0.004420135904983689, 'v1_vehicle_factors_1_FOLLOWED TOO CLOSELY'),
#  (0.0043524737917378905, 'v2_action_STOPPED'),
#  (0.004229690854588375, 'v1_type_VAN'),
#  (0.0041704200261016705, 'v1_vehicle_factors_1_UNSAFE LANE CHANGE'),
#  (0.004119094181776252, 'v2_type_HATCHBACK, 4 DOOR'),
#  (0.0039689800372217565, 'v2_most_harmful_event_MOTOR VEHICLE IN TRANSPORT'),
#  (0.003919616616472819, 'v1_driver_factors_1_OTHER IMPROPER DRIVING'),
#  (0.003914122333608441,
#   'v1_vehicle_factors_1_FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (0.003914112972221742, 'v1_vehicle_factors_1_OTHER IMPROPER DRIVING'),
#  (0.003869752907453659, 'v1_action_TURNING RIGHT'),
#  (0.00386097554353096, 'v1_most_harmful_event_UNKNOWN'),
#  (0.0038201290986283666, 'v1_driver_factors_1_HAD BEEN DRINKING'),
#  (0.003792387082042225, 'v2_driver_factors_1_UNKNOWN'),
#  (0.003782147475842189, 'v2_type_VAN'),
#  (0.003728412307578227, 'v2_driver_factors_1_APPARENTLY NORMAL'),
#  (0.0035710264401522286, 'v1_type_SEDAN, 2 DOOR'),
#  (0.00356824814544864, 'v1_all_events_1_UNKNOWN'),
#  (0.0034877364512322876, 'v2_all_events_1_UNKNOWN'),
#  (0.0034590945524030775, 'motorcyclist_YES'),
#  (0.0034040587858558003, 'motorcyclist_NO'),
#  (0.0033797783353469034, 'pedestrian_YES'),
#  (0.0032166472970411044, 'v1_type_HARDTOP, 4 DOOR'),
#  (0.0032121541932289975, 'v2_most_harmful_event_UNKNOWN'),
#  (0.003030350205465772, 'v1_most_harmful_event_MOTOR VEHICLE IN TRANSPORT'),
#  (0.003009486161140811, 'v1_vehicle_factors_1_HIT AND RUN'),
#  (0.0030027100306686907, 'v1_type_UTILITY'),
#  (0.002950058056033475, 'v1_action_NOT REPORTED'),
#  (0.002945027053258436, 'v2_all_events_1_SLOW/STOPPED VEHICLE'),
#  (0.002879863081469499, 'hwy_factors_1_BACKUP DUE TO REGULAR CONGESTION'),
#  (0.0028139217605300097, 'v2_action_TURNING LEFT'),
#  (0.002761487419220766, 'v2_type_UTILITY'),
#  (0.0027466200613268524, 'v1_type_SEDAN'),
#  (0.002744593392722927, 'crash_type_NON-COLLISION'),
#  (0.002738458310493618, 'factors_roadway_WET'),
#  (0.0027282818425954955, 'v2_vehicle_factors_1_UNKNOWN'),
#  (0.0027202540846701273, 'hwy_factors_1_OTHER HIGHWAY'),
#  (0.0026842299688702095, 'v1_all_events_1_SLOW/STOPPED VEHICLE'),
#  (0.0026703306705297978, 'v2_type_SEDAN, 2 DOOR'),
#  (0.002616120723906749, 'v1_driver_factors_1_INATTENTION/DISTRACTED'),
#  (0.0024710755406925056, 'v2_type_HARDTOP, 4 DOOR'),
#  (0.0023665066629827737, 'v2_most_harmful_event_SLOW/STOPPED VEHICLE'),
#  (0.002313067315876497, 'lighting_DUSK'),
#  (0.0022631354777516584, 'pedestrian_NO'),
#  (0.0022522536673154885, 'v2_type_SEDAN'),
#  (0.0022152750348533156, 'v1_vehicle_factors_1_OTHER'),
#  (0.0021189282922348123, 'v1_driver_distracted_UNKNOWN'),
#  (0.0020931164452809817, 'v2_all_events_1_PEDESTRIAN'),
#  (0.0020638077214455474, 'nonmotorist_factors_1_UNKNOWN'),
#  (0.002014432924433989, 'v1_most_harmful_event_SLOW/STOPPED VEHICLE'),
#  (0.0019597924554061908, 'v1_vehicle_factors_1_MADE AN IMPROPER TURN'),
#  (0.0019498279731370459, 'crash_type_SIDESWIPE, MEETING'),
#  (0.0018690677631312633, 'v1_vehicle_factors_2_ UNSAFE LANE CHANGE'),
#  (0.0018443875093200658, 'v2_action_UNKNOWN'),
#  (0.0017425364177182498, 'v1_type_MOTORCYCLE'),
#  (0.0017169091750250682, 'v1_all_events_1_PEDESTRIAN'),
#  (0.0016741549821244926, 'v1_type_HATCHBACK, 2 DOOR'),
#  (0.0015848838810214178, 'weather_RAIN'),
#  (0.0015730180299638752, 'v1_action_MAKING U-TURN'),
#  (0.0015337916602351349, 'v1_type_COUPE'),
#  (0.0015145205585627862, 'v2_action_TURNING RIGHT'),
#  (0.0015112750841189604, 'lighting_DAWN'),
#  (0.0015096424717584494, 'v1_vehicle_factors_2_ HIT AND RUN'),
#  (0.0014523385049335837, 'v2_action_PARKED'),
#  (0.001447654450639868, 'v1_driver_factors_1_DRUG INVOLVEMENT'),
#  (0.0014095237797986852, 'v1_type_HARDTOP, 2 DOOR'),
#  (0.0014061663476471079, 'lighting_DARK - NO LIGHTING'),
#  (0.0013735029939355532, 'pedalcyclist_YES'),
#  (0.00136596657378786, 'v2_type_MOTORCYCLE'),
#  (0.0013472559312304054, 'v2_type_HATCHBACK, 2 DOOR'),
#  (0.0013345522854380904, 'v2_type_UNKNOWN'),
#  (0.0013087498456981939, 'v2_type_BUS'),
#  (0.0013009728128216848, 'v1_all_events_1_NOT REPORTED'),
#  (0.0012985761694691675, 'v2_all_events_1_NOT REPORTED'),
#  (0.0012904443572584975, 'v1_type_CONVERTIBLE'),
#  (0.0012660360970204827,
#   'v1_driver_factors_1_FELL ASLEEP, FAINTED, FATIGUED, ETC.'),
#  (0.0012303673619326898, 'v2_type_SEMI'),
#  (0.0011999104032884983, 'v2_type_HARDTOP, 2 DOOR'),
#  (0.001199696379292039, 'hwy_factors_1_WORK ZONE (CONST. MAINT. UTILITY)'),
#  (0.0011776491834307832, 'v1_all_events_1_RAN OFF ROAD RIGHT'),
#  (0.0011734866379304687, 'v2_all_events_1_RAN OFF ROAD RIGHT'),
#  (0.0011164213809057178, 'v1_all_events_1_PEDAL CYCLE'),
#  (0.0011095106290457723, 'v1_type_STATION WAGON'),
#  (0.001107151604181552, 'v2_type_COUPE'),
#  (0.0011050094754194262, 'crash_type_HEAD-ON'),
#  (0.0010970722593320252, 'pedalcyclist_NO'),
#  (0.0010780662392931857, 'v1_action_BACKING UP'),
#  (0.0010457244922451774,
#   'v1_vehicle_factors_1_EXCEEDED AUTHORIZED SPEED LIMIT'),
#  (0.0010450505546293033, 'v1_type_SEMI'),
#  (0.0010426854537408153, 'v1_action_LEAVING LANE'),
#  (0.0010423469695590025, 'v2_all_events_1_OVERTURN/ROLLOVER'),
#  (0.0010216231190673423, 'v2_type_CONVERTIBLE'),
#  (0.0010121640997515005, 'v1_all_events_1_OVERTURN/ROLLOVER'),
#  (0.0009908882471904253, 'hwy_factors_1_WET, ICY, SNOW, SLUSH'),
#  (0.0009693580669650693, 'v1_most_harmful_event_PEDESTRIAN'),
#  (0.0009567141061286184, 'v1_driver_factors_1_ILLNESS'),
#  (0.0009556010820142138, 'v1_action_UNKNOWN'),
#  (0.0009353045594073807,
#   'v1_vehicle_factors_1_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR  AGGRESSIVE MANNER'),
#  (0.000918527636681289, 'v1_action_ENTERING LANE'),
#  (0.0009118371918672822, 'v2_type_STATION WAGON'),
#  (0.0009063459513675135, 'v2_all_events_2_ SLOW/STOPPED VEHICLE'),
#  (0.0008932795241759353, 'v1_all_events_2_ SLOW/STOPPED VEHICLE'),
#  (0.0008838366705260075, 'v2_all_events_1_RAN OFF ROAD LEFT'),
#  (0.0008723257742934724, 'v1_all_events_1_RAN OFF ROAD LEFT'),
#  (0.0008632511479914882, 'v2_all_events_1_PARKED MOTOR VEHICLE'),
#  (0.0008610681171488059, 'crash_type_BACKING'),
#  (0.000849462451503269, 'v1_vehicle_factors_3_ UNSAFE LANE CHANGE'),
#  (0.0008493180049508759, 'v2_all_events_1_PEDAL CYCLE'),
#  (0.0008431683917830208, 'v2_all_events_2_ OVERTURN/ROLLOVER'),
#  (0.0008326606090593803, 'v1_action_STOPPED'),
#  (0.0008287555440215817, 'hwy_factors_1_DEBRIS'),
#  (0.0008220725048788486, 'v1_type_MOPED'),
#  (0.0008045666162363747, 'v1_all_events_2_ OVERTURN/ROLLOVER'),
#  (0.0007940815742633142, 'v1_all_events_1_PARKED MOTOR VEHICLE'),
#  (0.000784091884864413, 'v2_vehicle_factors_1_HIT AND RUN'),
#  (0.0007566620615988968, 'nonmotorist_factors_1_IMPROPER CROSSING'),
#  (0.0007163888051055935, 'v1_all_events_1_MEDIAN BARRIER'),
#  (0.0007157975501128498, 'hwy_factors_1_WEATHER'),
#  (0.000715271985006866, 'v2_all_events_1_MEDIAN BARRIER'),
#  (0.0007087704055870107, 'v2_type_MOPED'),
#  (0.00070511210848217, 'v1_action_OTHER'),
#  (0.0006989536092415019, 'v1_most_harmful_event_OVERTURN/ROLLOVER'),
#  (0.0006967606622202106, 'v1_type_BUS'),
#  (0.0006820560767415944, 'weather_CLOUDY: RAIN'),
#  (0.000667026380241502, 'v2_all_events_2_ FENCE/WALL'),
#  (0.0006382750575645419, 'v2_vehicle_factors_1_OTHER'),
#  (0.0006357744867556186, 'v1_driver_distracted_ELECTRONIC EQUIPMENT'),
#  (0.0006253208342947489, 'v1_all_events_2_ FENCE/WALL'),
#  (0.0005939207078825126, 'v1_type_TRACTOR TRUCK, DIESEL'),
#  (0.000590042042165762, 'v1_driver_distracted_OTHER'),
#  (0.0005770518576846492,
#   'hwy_factors_1_BACKUP DUE TO PRIOR NON-RECURRING INCIDENT'),
#  (0.000576699759053293, 'v1_vehicle_factors_1_UNSAFE BACKING'),
#  (0.0005764345672525335, 'hwy_factors_1_GLARE'),
#  (0.0005745412863755166, 'v1_vehicle_factors_1_MECHANICAL DEFECTS'),
#  (0.0005740275273695293, 'v2_type_TRACTOR TRUCK, DIESEL'),
#  (0.0005740065827774915, 'v1_all_events_1_FENCE/WALL'),
#  (0.000566771362248334, 'v2_all_events_1_OTHER MOVABLE OBJECT'),
#  (0.0005666400073477436, 'v2_all_events_1_FENCE/WALL'),
#  (0.000565686817666429,
#   'v1_driver_distracted_EXTERNAL DISTRACTION (OUTSIDE THE VEHICLE)'),
#  (0.0005592887964018868,
#   'v1_vehicle_factors_2_ DISREGARDED TRAFFIC SIGNS, SIGNALS, ROAD MARKINGS'),
#  (0.0005548980945350136, 'hwy_factors_1_BACKUP DUE TO PRIOR CRASH'),
#  (0.0005528479485689251, 'v1_all_events_3_ OVERTURN/ROLLOVER'),
#  (0.0005499459492308575, 'v2_vehicle_factors_1_OTHER IMPROPER DRIVING'),
#  (0.0005397973132054261, 'hwy_factors_2_ WET, ICY, SNOW, SLUSH'),
#  (0.0005390146517968166,
#   'v1_vehicle_factors_2_ FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (0.0005285901556237846, 'v1_driver_distracted_OTHER INSIDE THE VEHICLE'),
#  (0.0005234396990105653, 'v2_all_events_1_CURB'),
#  (0.000521868917966527, 'hwy_factors_1_INACTIVE WORK ZONE'),
#  (0.000521132010357134, 'v2_action_CHANGING LANES'),
#  (0.0005193482440238429, 'v1_most_harmful_event_PEDAL CYCLE'),
#  (0.0005154276485686072, 'v1_action_PASSING OTHER VEHICLE'),
#  (0.0005110214479823819, 'animaltype_NO'),
#  (0.0005109611422220584, 'v1_vehicle_factors_1_OBJECT AVOIDANCE'),
#  (0.0005098933571343879, 'v2_all_events_3_ OVERTURN/ROLLOVER'),
#  (0.00048750989000512636, 'v2_all_events_2_ RAN OFF ROAD RIGHT'),
#  (0.00048681611437149567, 'v1_all_events_1_CROSS MEDIAN/CENTERLINE'),
#  (0.00048306518284425116, 'v1_all_events_1_CURB'),
#  (0.00048179725922254014, 'hwy_factors_1_ACTIVE WORK ZONE'),
#  (0.0004816814391938993, 'v1_vehicle_factors_2_ OTHER IMPROPER DRIVING'),
#  (0.0004811443903850075, 'v2_vehicle_factors_1_FAILED TO YIELD RIGHT OF WAY'),
#  (0.00046811614351512077, 'v2_all_events_1_CROSS MEDIAN/CENTERLINE'),
#  (0.00046509626849809737, 'v1_all_events_2_ RAN OFF ROAD RIGHT'),
#  (0.0004562912959172468, 'v2_all_events_1_OTHER NON-COLLISION'),
#  (0.0004555703579489297, 'v1_all_events_1_OTHER MOVABLE OBJECT'),
#  (0.00044647838018902234, 'v1_vehicle_factors_2_ MADE AN IMPROPER TURN'),
#  (0.000439858912285799, 'v1_all_events_2_ MEDIAN BARRIER'),
#  (0.0004379868498045489, 'v1_all_events_1_OTHER NON-COLLISION'),
#  (0.0004379861536477028, 'v1_vehicle_factors_1_WRONG SIDE OR WRONG WAY'),
#  (0.0004376445471630521, 'v2_all_events_2_ MEDIAN BARRIER'),
#  (0.0004343727343848391, 'v1_type_WAGON'),
#  (0.00043340173697046066, 'v1_action_NEGOTIATING A CURVE'),
#  (0.000432915619988315, 'v1_type_OTHER'),
#  (0.0004247798371666421, 'v1_driver_factors_1_HIT AND RUN'),
#  (0.00041824375680261027, 'v1_type_HATCHBACK/FASTBACK'),
#  (0.0004153621906251184, 'v1_vehicle_factors_4_ UNSAFE LANE CHANGE'),
#  (0.000412634288253899, 'v1_most_harmful_event_PARKED MOTOR VEHICLE'),
#  (0.0003993354949482222, 'v1_vehicle_factors_1_DROVE LEFT OF CENTER'),
#  (0.00039727027273901174, 'v1_driver_factors_2_ DRUG INVOLVEMENT'),
#  (0.00038767539884082205, 'v1_driver_distracted_RADIO/CD PLAYER'),
#  (0.00038537861205002787, 'v1_all_events_2_ TREE/SHRUB'),
#  (0.0003841389369408378, 'v1_driver_factors_1_OBSTRUCTED VIEW'),
#  (0.0003807672723903363, 'v1_all_events_2_ NOT REPORTED'),
#  (0.0003802238436779157, 'v2_all_events_2_ NOT REPORTED'),
#  (0.00037684824454373703, 'v2_all_events_2_ TREE/SHRUB'),
#  (0.0003737308032008788, 'hwy_factors_2_ WORK ZONE (CONST. MAINT. UTILITY)'),
#  (0.00037266475328112143, 'v1_action_TRAVELING WRONG WAY'),
#  (0.0003663990260840176, 'v2_type_HATCHBACK/FASTBACK'),
#  (0.0003656951077981384, 'v1_type_FLATBED OR PLATFORM'),
#  (0.0003633231783668373, 'v1_vehicle_factors_2_ RAN OFF ROAD'),
#  (0.0003607416204042915, 'v1_vehicle_factors_1_RAN OFF ROAD'),
#  (0.0003588112237057714, 'v2_all_events_2_ LIGHT/LUMINARY SUPPORT'),
#  (0.00035020354541792447, 'v1_all_events_2_ LIGHT/LUMINARY SUPPORT'),
#  (0.00034421450001577463, 'animaltype_HORSE'),
#  (0.00034132573584716555, 'v2_type_TOW TRUCK/WRECKER'),
#  (0.0003362253239409084, 'v1_vehicle_factors_1_OVER-CORRECTING/OVER-STEERING'),
#  (0.00033409156509790256, 'v2_type_WAGON'),
#  (0.0003326699641726239, 'v2_all_events_2_ CURB'),
#  (0.0003319214686522293, 'v1_all_events_2_ CURB'),
#  (0.0003317436534312364, 'v2_all_events_2_ RAN OFF ROAD LEFT'),
#  (0.0003226419431516767, 'v2_most_harmful_event_OVERTURN/ROLLOVER'),
#  (0.00032238565087121837, 'v2_type_FLATBED OR PLATFORM'),
#  (0.00032190134023570276, 'v2_driver_factors_1_HAD BEEN DRINKING'),
#  (0.0003195070668975668, 'v2_action_MAKING U-TURN'),
#  (0.00031869712760744837, 'v1_all_events_2_ RAN OFF ROAD LEFT'),
#  (0.00031717558732537513, 'v1_vehicle_factors_3_ HIT AND RUN'),
#  (0.00031662493277877853, 'v1_all_events_3_ FENCE/WALL'),
#  (0.0003153286169358322, 'v2_all_events_3_ FENCE/WALL'),
#  (0.0002955595009390912, 'v1_most_harmful_event_OTHER MOVABLE OBJECT'),
#  (0.0002920417298079225, 'v1_type_DUMP'),
#  (0.00029186530761576997, 'v1_driver_factors_1_PHYSICAL IMPAIRMENT'),
#  (0.0002916609008630684,
#   'v1_vehicle_factors_2_ OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR  AGGRESSIVE MANNER'),
#  (0.0002892759325482806, 'v1_most_harmful_event_MEDIAN BARRIER'),
#  (0.0002854945795888735, 'v2_vehicle_factors_1_FOLLOWED TOO CLOSELY'),
#  (0.0002851806102259936, 'v2_type_OTHER'),
#  (0.0002835375648425039, 'v1_vehicle_factors_3_ RAN OFF ROAD'),
#  (0.00028115543181371483,
#   'v2_vehicle_factors_1_DISREGARDED TRAFFIC SIGNS, SIGNALS, ROAD MARKINGS'),
#  (0.00027973676275679847, 'nonmotorist_factors_1_DARTING'),
#  (0.00027296908451053705, 'v1_vehicle_factors_2_ DROVE LEFT OF CENTER'),
#  (0.0002723503805080067, 'v1_driver_factors_2_ OTHER IMPROPER DRIVING'),
#  (0.0002716010269270626, 'v1_all_events_1_CONCRETE TRAFFIC BARRIER'),
#  (0.0002673741385310447, 'v1_all_events_1_FIRE/EXPLOSION'),
#  (0.0002634142802465585,
#   'v1_all_events_1_EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (0.00026331541754025413, 'v1_type_TOW TRUCK/WRECKER'),
#  (0.0002616086004525073, 'v1_type_MOTORSCOOTER'),
#  (0.0002601873541090605, 'crash_type_REAR-TO-REAR'),
#  (0.0002584599074808024, 'v1_most_harmful_event_CONCRETE TRAFFIC BARRIER'),
#  (0.00025843697078662255, 'lighting_DARK - CONTINUOUS ROADWAY LIGHTING'),
#  (0.0002582970038113016, 'v2_all_events_1_CONCRETE TRAFFIC BARRIER'),
#  (0.0002511359240000117,
#   'v2_all_events_1_EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (0.0002469729077272957, 'v1_all_events_3_ TREE/SHRUB'),
#  (0.00023969335387319412, 'v2_action_NOT REPORTED'),
#  (0.0002394712821249139, 'v2_all_events_1_FIRE/EXPLOSION'),
#  (0.0002385807940733968, 'v2_all_events_2_ EMBANKMENT'),
#  (0.00023823986695140203, 'v1_all_events_2_ OTHER POST, POLE OR SUPPORT'),
#  (0.00023806362261507167, 'v1_most_harmful_event_FENCE/WALL'),
#  (0.00023804730932349964, 'v2_all_events_3_ TREE/SHRUB'),
#  (0.00023760548883876062,
#   'v2_vehicle_factors_1_EXCEEDED AUTHORIZED SPEED LIMIT'),
#  (0.00023179302336445292, 'v2_vehicle_factors_1_UNSAFE LANE CHANGE'),
#  (0.00023167626098431605, 'v2_type_TRACTOR TRUCK, GASOLINE'),
#  (0.00023114418826785334,
#   'v1_vehicle_factors_2_ OVER-CORRECTING/OVER-STEERING'),
#  (0.000226963570646534, 'v2_all_events_2_ CONCRETE TRAFFIC BARRIER'),
#  (0.00022685029449151888,
#   'v2_driver_factors_1_FELL ASLEEP, FAINTED, FATIGUED, ETC.'),
#  (0.00022548009255648387, 'v2_action_NEGOTIATING A CURVE'),
#  (0.00022242297871265555, 'v1_vehicle_factors_2_ UNKNOWN'),
#  (0.000220037756506939, 'v1_all_events_2_ CONCRETE TRAFFIC BARRIER'),
#  (0.00021876735312356395, 'v2_all_events_2_ OTHER POST, POLE OR SUPPORT'),
#  (0.0002126130407280231, 'v1_all_events_2_ EMBANKMENT'),
#  (0.0002121153160819493, 'crash_type_UNKNOWN'),
#  (0.0002119697317755662, 'v2_type_DUMP'),
#  (0.00021126451184486206, 'v1_vehicle_factors_2_ ROAD DEFECT'),
#  (0.0002077757544909396, 'v1_vehicle_factors_2_ FOLLOWED TOO CLOSELY'),
#  (0.00020686732046144653, 'weather_UNKNOWN'),
#  (0.0002053346206359134, 'v1_all_events_2_ UTILITY POLE'),
#  (0.00020526265887357292, 'v2_driver_factors_1_OTHER IMPROPER DRIVING'),
#  (0.00020450943843655292, 'factors_roadway_ICE'),
#  (0.00020015222578518944, 'v1_driver_distracted_CHILDREN'),
#  (0.00019920754314871594, 'v1_all_events_2_ PARKED MOTOR VEHICLE'),
#  (0.00019893262641232454, 'v2_all_events_2_ PARKED MOTOR VEHICLE'),
#  (0.00019806835244174647, 'v2_vehicle_factors_1_OBJECT AVOIDANCE'),
#  (0.0001967300622985293, 'v1_action_LEAVING PARK POSITION'),
#  (0.00019634920841803908, 'v1_all_events_4_ OVERTURN/ROLLOVER'),
#  (0.00019499414239897652, 'v2_all_events_4_ OVERTURN/ROLLOVER'),
#  (0.00019475444333727268, 'v1_all_events_1_LIGHT/LUMINARY SUPPORT'),
#  (0.00019336761087293788,
#   'v2_vehicle_factors_1_FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (0.0001926010398606971, 'v1_type_3-DOOR'),
#  (0.00018960472802200207, 'v2_all_events_2_ UTILITY POLE'),
#  (0.00018939560242053977, 'v2_type_LIMOUSINE'),
#  (0.0001879368998480643, 'v2_all_events_3_ MEDIAN BARRIER'),
#  (0.00018743927059425858, 'v2_most_harmful_event_PARKED MOTOR VEHICLE'),
#  (0.00018654354694401924, 'v2_all_events_1_LIGHT/LUMINARY SUPPORT'),
#  (0.0001846347183734018, 'v2_all_events_3_ LIGHT/LUMINARY SUPPORT'),
#  (0.00018393227936625557, 'v1_all_events_3_ LIGHT/LUMINARY SUPPORT'),
#  (0.00018229123001051365,
#   'nonmotorist_factors_1_FAILURE TO OBEY TRAFFIC SIGNS, SIGNALS, OR OFFICER'),
#  (0.0001820547490405626,
#   'v2_vehicle_factors_1_DRIVING TOO FAST FOR CONDITIONS'),
#  (0.00018038895908892817,
#   'nonmotorist_factors_1_FAILURE TO YIELD RIGHT OF WAY'),
#  (0.0001768912166363686, 'v1_all_events_3_ MEDIAN BARRIER'),
#  (0.00017479783089756478, 'v2_type_MOTORSCOOTER'),
#  (0.0001733419014577217, 'v2_all_events_3_ EMBANKMENT'),
#  (0.00017255259742657368, 'v1_driver_factors_2_ HAD BEEN DRINKING'),
#  (0.00017254323279312502, 'weather_BLOWING SNOW'),
#  (0.000170598413403597, 'hwy_factors_1_OTHER ENVIRONMENTAL'),
#  (0.00017048244838142838, 'v2_all_events_1_IMPACT ATTENUATOR/CRASH CUSHION'),
#  (0.00016913914620041455, 'v1_type_LIMOUSINE'),
#  (0.00016864060540727903, 'v1_type_TRACTOR TRUCK, GASOLINE'),
#  (0.00016673987043778297, 'v1_driver_distracted_CELL PHONE'),
#  (0.00016613579144609828, 'v1_most_harmful_event_RAN OFF ROAD RIGHT'),
#  (0.00016383190261995463,
#   'v1_all_events_2_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (0.0001637622171137352,
#   'v1_vehicle_factors_2_ DRIVING TOO FAST FOR CONDITIONS'),
#  (0.00016306539406276045, 'v1_all_events_1_TREE/SHRUB'),
#  (0.00016215391915758035, 'v1_all_events_2_ HIGHWAY TRAFFIC SIGN POST'),
#  (0.0001598719701808018,
#   'v2_all_events_2_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (0.00015895688095197587, 'v1_all_events_2_ PEDESTRIAN'),
#  (0.0001587609020221402, 'v2_all_events_2_ HIGHWAY TRAFFIC SIGN POST'),
#  (0.00015833133738735864, 'v1_all_events_1_CROSS MEDIAN'),
#  (0.00015827752574281085, 'hwy_factors_1_ROAD OBSTRUCTION'),
#  (0.00015663382809601482, 'v1_driver_distracted_CELL PHONE (TEXTING)'),
#  (0.00015602460475016777, 'v1_all_events_1_IMPACT ATTENUATOR/CRASH CUSHION'),
#  (0.00015549798225179175, 'v1_all_events_3_ SLOW/STOPPED VEHICLE'),
#  (0.00015532368632413334, 'v1_all_events_3_ EMBANKMENT'),
#  (0.0001550922251902536, 'nonmotorist_factors_1_WRONG SIDE OF ROAD'),
#  (0.00015367084351834557, 'v1_vehicle_factors_5_ UNSAFE LANE CHANGE'),
#  (0.0001515259401135867, 'v2_all_events_2_ PEDESTRIAN'),
#  (0.0001513930732693537, 'v2_all_events_1_CROSS MEDIAN'),
#  (0.00015087488994235305, 'v2_all_events_1_TREE/SHRUB'),
#  (0.0001505098231126676, 'hwy_factors_2_ BACKUP DUE TO REGULAR CONGESTION'),
#  (0.00014933629056292834, 'v1_most_harmful_event_OTHER NON-COLLISION'),
#  (0.00014921422625571897, 'v1_type_MOTORBIKE'),
#  (0.00014850168800022802, 'hwy_factors_1_ANIMAL IN ROADWAY'),
#  (0.00014839557770053214, 'nonmotorist_factors_2_ DARTING'),
#  (0.00014802383119638486, 'v2_all_events_2_ OTHER MOVABLE OBJECT'),
#  (0.00014600454569135723, 'weather_SEVERE CROSSWINDS'),
#  (0.00014590973226159452, 'v2_all_events_3_ SLOW/STOPPED VEHICLE'),
#  (0.00014485849683433275, 'v1_most_harmful_event_FIRE/EXPLOSION'),
#  (0.00014435977186224823, 'v1_all_events_2_ OTHER MOVABLE OBJECT'),
#  (0.00014187383116262602, 'v1_most_harmful_event_CURB'),
#  (0.00013980412696152253, 'v1_vehicle_factors_3_ OTHER IMPROPER DRIVING'),
#  (0.0001395838890930838, 'v1_all_events_1_CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (0.00013905819420273545, 'lighting_DARK - UNKNOWN LIGHTING'),
#  (0.00013689940882075435, 'v2_type_AMBULANCE'),
#  (0.00013533401596628434, 'v2_all_events_2_ CROSS MEDIAN/CENTERLINE'),
#  (0.00013440824373298782, 'v2_action_ENTERING LANE'),
#  (0.00013358218352405883, 'weather_BLOWING SAND, SOIL, DIRT, SNOW'),
#  (0.00013253491472105906, 'v2_action_OTHER'),
#  (0.00013218723831796985, 'v1_all_events_2_ CROSS MEDIAN/CENTERLINE'),
#  (0.00013185180036993463,
#   'v1_vehicle_factors_3_ OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR  AGGRESSIVE MANNER'),
#  (0.00012972331899245874,
#   'v1_vehicle_factors_2_ EXCEEDED AUTHORIZED SPEED LIMIT'),
#  (0.00012969248668491995, 'v1_all_events_1_CROSS CENTERLINE'),
#  (0.00012662342884288194, 'v2_vehicle_factors_1_MADE AN IMPROPER TURN'),
#  (0.00012645815602567524, 'v2_all_events_4_ FENCE/WALL'),
#  (0.00012623370467363155, 'v1_type_VAN CAMPER'),
#  (0.00012561755636505002, 'v2_all_events_1_CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (0.0001255348334753712, 'v2_all_events_1_CROSS CENTERLINE'),
#  (0.00012407815193424151, 'v1_all_events_2_ GUARDRAIL FACE'),
#  (0.0001237071301148805, 'v1_vehicle_factors_2_ VISIBILITY OBSTRUCTED'),
#  (0.00012340628570956997, 'weather_SLEET, HAIL (FREEZING RAIN OR DRIZZLE)'),
#  (0.00012244739081154163, 'v1_all_events_3_ RAN OFF ROAD RIGHT'),
#  (0.00012159939960845372, 'animaltype_UNKNOWN'),
#  (0.00012158968145686967, 'v1_driver_distracted_EATING'),
#  (0.00012135101420202004, 'hwy_factors_1_VISUAL OBSTRUCTION(S)'),
#  (0.00012000043385100361, 'v2_all_events_3_ RAN OFF ROAD RIGHT'),
#  (0.00011996087229863611,
#   'v1_vehicle_factors_3_ FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (0.0001194632078643682, 'v1_vehicle_factors_3_ DROVE LEFT OF CENTER'),
#  (0.00011906734544343273, 'hwy_factors_2_ OTHER HIGHWAY'),
#  (0.00011873046272397323, 'nonmotorist_factors_2_ IMPROPER CROSSING'),
#  (0.00011798246702407054, 'v1_all_events_4_ FENCE/WALL'),
#  (0.00011796153242912025, 'v2_all_events_2_ GUARDRAIL FACE'),
#  (0.00011663750865823232, 'nonmotorist_factors_1_NOT VISIBLE (DARK CLOTHING)'),
#  (0.00011655278285749304,
#   'v1_all_events_3_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (0.00011601463686619661,
#   'v2_all_events_3_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (0.00011520554707154841, 'v1_type_GARBAGE OR REFUSE'),
#  (0.00011431343472476403, 'v2_vehicle_factors_2_ UNSAFE LANE CHANGE'),
#  (0.00011248201612332534, 'v2_type_3-DOOR'),
#  (0.00011185791062210257,
#   'nonmotorist_factors_1_LYING AND/OR ILLEGALLY IN ROADWAY'),
#  (0.00011180099084620702, 'v1_type_VANETTE'),
#  (0.00011020529820689747, 'nonmotorist_factors_1_OTHER'),
#  (0.0001096067380879773, 'v2_action_LEAVING LANE'),
#  (0.00010921835965745553, 'v2_vehicle_factors_1_MECHANICAL DEFECTS'),
#  (0.00010850741853974532, 'v2_all_events_1_OTHER POST, POLE OR SUPPORT'),
#  (0.00010792145906235135, 'v2_type_GARBAGE OR REFUSE'),
#  (0.00010779509169545927, 'v2_all_events_3_ NOT REPORTED'),
#  (0.00010638261156452802, 'v1_all_events_3_ OTHER POST, POLE OR SUPPORT'),
#  (0.0001059587860619933, 'v1_type_CONSTRUCTION VEHICLE'),
#  (0.00010559815420521982, 'v2_all_events_3_ CONCRETE TRAFFIC BARRIER'),
#  (0.00010548934960411003, 'v1_all_events_3_ NOT REPORTED'),
#  (0.00010345130627219961, 'v1_type_MOTORIZED HOME'),
#  (0.00010291588443583777, 'v2_all_events_1_HIGHWAY TRAFFIC SIGN POST'),
#  (0.00010286130886912669, 'v1_most_harmful_event_RAN OFF ROAD LEFT'),
#  (0.00010284851971982023, 'v1_all_events_2_ DITCH'),
#  (0.00010124396249443323, 'v1_all_events_1_HIGHWAY TRAFFIC SIGN POST'),
#  (0.00010022032881536789, 'v1_all_events_1_OTHER POST, POLE OR SUPPORT'),
#  (0.00010009116675149529, 'v2_type_PICKUP WITH MOUNTED CAMPER'),
#  (9.941308454349492e-05, 'v1_all_events_4_ TREE/SHRUB'),
#  (9.819159083916706e-05, 'v1_vehicle_factors_2_ MECHANICAL DEFECTS'),
#  (9.771859858527706e-05, 'v1_all_events_1_GUARDRAIL FACE'),
#  (9.769384793823279e-05, 'v1_all_events_3_ CONCRETE TRAFFIC BARRIER'),
#  (9.708021680754976e-05, 'v2_all_events_4_ TREE/SHRUB'),
#  (9.697157790060587e-05, 'v1_all_events_3_ RAN OFF ROAD LEFT'),
#  (9.676943024280741e-05, 'v1_vehicle_factors_4_ RAN OFF ROAD'),
#  (9.670720931339509e-05, 'v2_all_events_3_ RAN OFF ROAD LEFT'),
#  (9.571874561593494e-05, 'v2_all_events_1_UTILITY POLE'),
#  (9.41873306069169e-05, 'v2_type_VANETTE'),
#  (9.35531128383586e-05, 'v2_all_events_3_ OTHER POST, POLE OR SUPPORT'),
#  (9.306302434341307e-05, 'v2_type_CHASSIS AND CAB'),
#  (9.301123350792771e-05, 'v1_most_harmful_event_EMBANKMENT'),
#  (9.265567792365208e-05, 'v2_all_events_1_UNKNOWN NON-COLLISION'),
#  (9.254835015516456e-05, 'v2_type_VAN CAMPER'),
#  (9.244892904231574e-05, 'v2_all_events_2_ DITCH'),
#  (9.237515908392374e-05, 'v2_all_events_1_GUARDRAIL FACE'),
#  (9.124626643887833e-05, 'v1_type_PICKUP WITH MOUNTED CAMPER'),
#  (9.054939768823216e-05, 'v1_type_CHASSIS AND CAB'),
#  (8.978794798867415e-05, 'v2_action_PASSING OTHER VEHICLE'),
#  (8.920109467948138e-05, 'v1_vehicle_factors_2_ OBJECT AVOIDANCE'),
#  (8.859166589156858e-05, 'v1_vehicle_factors_4_ HIT AND RUN'),
#  (8.85349964037035e-05, 'v1_all_events_1_UNKNOWN MOVABLE OBJECT'),
#  (8.811576889419245e-05, 'v2_all_events_3_ PARKED MOTOR VEHICLE'),
#  (8.700035825876228e-05, 'v1_most_harmful_event_TREE/SHRUB'),
#  (8.68965980284921e-05, 'v2_driver_factors_1_DRUG INVOLVEMENT'),
#  (8.674294927451258e-05, 'v2_all_events_3_ DITCH'),
#  (8.561318409572195e-05, 'v1_type_PALLET'),
#  (8.53474257957177e-05, 'v2_all_events_3_ CURB'),
#  (8.494991277332092e-05, 'v1_all_events_1_UTILITY POLE'),
#  (8.443451081424451e-05, 'v2_vehicle_factors_1_DRIVERLESS VEHICLE'),
#  (8.339089771431933e-05, 'v1_type_CONCRETE MIXER'),
#  (8.325517019157973e-05, 'v2_type_PALLET'),
#  (8.287951601896333e-05,
#   'v1_all_events_1_OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (8.274834202530028e-05, 'v1_all_events_3_ UTILITY POLE'),
#  (8.166919155753404e-05, 'v1_all_events_3_ CURB'),
#  (8.147462544102366e-05, 'v1_all_events_3_ PARKED MOTOR VEHICLE'),
#  (8.13398187589047e-05, 'v2_type_CONSTRUCTION VEHICLE'),
#  (8.124560886027394e-05,
#   'nonmotorist_factors_1_INATTENTIVE (TALKING, EATING, ETC.)'),
#  (8.069987109787876e-05, 'v1_action_PARKED'),
#  (8.024213292587766e-05, 'v1_all_events_1_UNKNOWN NON-COLLISION'),
#  (8.018558767438954e-05, 'v2_type_MOTORBIKE'),
#  (7.865083050810368e-05,
#   'nonmotorist_factors_2_ FAILURE TO YIELD RIGHT OF WAY'),
#  (7.71178879811778e-05, 'v2_vehicle_factors_1_RAN OFF ROAD'),
#  (7.625310316722178e-05, 'hwy_factors_1_RUTS, HOLES, BUMPS'),
#  (7.621399078555795e-05,
#   'v1_vehicle_factors_3_ OVER-CORRECTING/OVER-STEERING'),
#  (7.565860254591995e-05, 'v2_most_harmful_event_MEDIAN BARRIER'),
#  (7.454210848220546e-05, 'v1_type_AMBULANCE'),
#  (7.434377484591728e-05, 'v1_all_events_2_ IMPACT ATTENUATOR/CRASH CUSHION'),
#  (7.401666522356345e-05, 'v2_action_BACKING UP'),
#  (7.378001101856161e-05,
#   'v2_all_events_1_OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (7.341540791529783e-05, 'v1_most_harmful_event_CROSS MEDIAN/CENTERLINE'),
#  (7.319200447856676e-05, 'v1_all_events_3_ OTHER MOVABLE OBJECT'),
#  (7.275405517755616e-05, 'v1_type_MULTI-WHEEL'),
#  (7.232595666785477e-05, 'v1_all_events_1_EMBANKMENT'),
#  (7.20958802098241e-05,
#   'v2_vehicle_factors_1_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR  AGGRESSIVE MANNER'),
#  (7.208555424135932e-05, 'v2_all_events_3_ UTILITY POLE'),
#  (7.167822724669367e-05, 'v2_all_events_2_ OTHER NON-COLLISION'),
#  (7.060890154492e-05, 'v2_all_events_1_SEPARATION OF UNITS'),
#  (7.05923076015119e-05, 'v2_all_events_2_ IMPACT ATTENUATOR/CRASH CUSHION'),
#  (7.002470149032655e-05,
#   'v1_most_harmful_event_EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (6.998333272753072e-05, 'v2_all_events_3_ OTHER MOVABLE OBJECT'),
#  (6.967719430858764e-05, 'v2_all_events_1_UNKNOWN MOVABLE OBJECT'),
#  (6.95494797255437e-05, 'v2_type_TANKER'),
#  (6.934532002829107e-05, 'v1_all_events_1_SEPARATION OF UNITS'),
#  (6.859721327535516e-05, 'v2_all_events_2_ FIRE/EXPLOSION'),
#  (6.805154410446326e-05, 'v2_type_CONCRETE MIXER'),
#  (6.750480342508279e-05, 'weather_FOG, SMOG, SMOKE'),
#  (6.741099470140903e-05, 'v1_all_events_3_ DITCH'),
#  (6.720731979409813e-05, 'v1_action_RACING'),
#  (6.720570501344361e-05, 'v1_vehicle_factors_1_DRIVERLESS VEHICLE'),
#  (6.718371920327846e-05, 'v1_all_events_1_WORK ZONE MAINTENANCE EQUIPMENT'),
#  (6.70611072620733e-05, 'v2_all_events_2_ CROSS MEDIAN'),
#  (6.638059128175122e-05, 'v2_most_harmful_event_OTHER NON-COLLISION'),
#  (6.610846762088902e-05, 'v1_all_events_2_ FIRE/EXPLOSION'),
#  (6.606664675207372e-05, 'v2_most_harmful_event_OTHER MOVABLE OBJECT'),
#  (6.60433798979913e-05, 'v1_all_events_2_ OTHER NON-COLLISION'),
#  (6.60064386949523e-05, 'v1_all_events_2_ CROSS MEDIAN'),
#  (6.539578317512326e-05, 'v2_type_MOTORIZED HOME'),
#  (6.436917851863959e-05, 'weather_OTHER'),
#  (6.432237750963203e-05, 'hwy_factors_1_WORN TRAFFIC SURFACE'),
#  (6.431466726141737e-05, 'v2_all_events_1_WORK ZONE MAINTENANCE EQUIPMENT'),
#  (6.423933916504977e-05, 'v1_vehicle_factors_3_ OBJECT AVOIDANCE'),
#  (6.353524009291169e-05, 'v2_most_harmful_event_FENCE/WALL'),
#  (6.153472895136135e-05, 'v1_vehicle_factors_4_ ROAD DEFECT'),
#  (5.967381868617961e-05,
#   'v2_most_harmful_event_CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (5.914917476782068e-05, 'v1_driver_distracted_ANIMALS'),
#  (5.898231241293265e-05, 'v1_type_TANKER'),
#  (5.889355611346589e-05, 'v1_all_events_3_ HIGHWAY TRAFFIC SIGN POST'),
#  (5.855878351628417e-05, 'v1_all_events_5_ OVERTURN/ROLLOVER'),
#  (5.8508142215504824e-05,
#   'v2_all_events_4_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (5.8019893517904205e-05, 'v2_driver_factors_1_ILLNESS'),
#  (5.79450883604173e-05, 'v2_all_events_5_ OVERTURN/ROLLOVER'),
#  (5.7337088140968926e-05, 'v1_type_HARDTOP'),
#  (5.67711171462591e-05,
#   'v1_all_events_4_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (5.66704301656251e-05, 'v2_vehicle_factors_2_ UNKNOWN'),
#  (5.597130417432857e-05,
#   'v1_most_harmful_event_IMPACT ATTENUATOR/CRASH CUSHION'),
#  (5.5277136952992796e-05, 'v2_all_events_4_ MEDIAN BARRIER'),
#  (5.468453786775182e-05, 'v2_all_events_1_EMBANKMENT'),
#  (5.4531741788233117e-05, 'v2_all_events_2_ GUARDRAIL END'),
#  (5.442234927413839e-05, 'v1_driver_factors_3_ OTHER IMPROPER DRIVING'),
#  (5.4098841645130355e-05, 'v1_all_events_2_ GUARDRAIL END'),
#  (5.344063224195641e-05, 'v1_all_events_2_ REENTERING ROADWAY'),
#  (5.3166358406184565e-05, 'v1_most_harmful_event_DITCH'),
#  (5.282751470780113e-05, 'v2_all_events_3_ HIGHWAY TRAFFIC SIGN POST'),
#  (5.275692738603846e-05, 'v1_vehicle_factors_2_ WRONG SIDE OR WRONG WAY'),
#  (5.26637109705259e-05, 'v1_most_harmful_event_LIGHT/LUMINARY SUPPORT'),
#  (5.2043594071243156e-05, 'v1_all_events_4_ MEDIAN BARRIER'),
#  (5.202387254892847e-05,
#   'v1_most_harmful_event_FELL/JUMPED FROM MOTOR VEHICLE'),
#  (5.19183256755779e-05, 'lighting_DARK - SPOT ROADWAY LIGHTING'),
#  (5.139993071290127e-05, 'v1_all_events_3_ REENTERING ROADWAY'),
#  (5.1090800913884456e-05, 'v2_all_events_4_ EMBANKMENT'),
#  (5.1089840395416565e-05, 'v1_all_events_4_ EMBANKMENT'),
#  (5.068262143088652e-05, 'v1_all_events_4_ SLOW/STOPPED VEHICLE'),
#  (5.039092774490981e-05, 'v1_all_events_1_GUARDRAIL END'),
#  (5.01716526258274e-05, 'v2_vehicle_factors_2_ ROAD DEFECT'),
#  (4.9560400814658014e-05, 'v2_most_harmful_event_CONCRETE TRAFFIC BARRIER'),
#  (4.955023018119885e-05, 'v2_driver_factors_1_HIT AND RUN'),
#  (4.94953892744323e-05, 'v1_vehicle_factors_4_ DROVE LEFT OF CENTER'),
#  (4.930847191017139e-05, 'v2_action_DRIVERLESS-MOVING VEHICLE'),
#  (4.902704283657459e-05, 'v2_all_events_4_ LIGHT/LUMINARY SUPPORT'),
#  (4.8981838408828004e-05, 'v1_all_events_4_ LIGHT/LUMINARY SUPPORT'),
#  (4.885166417001705e-05,
#   'v1_most_harmful_event_CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (4.8634000985873345e-05, 'v1_vehicle_factors_3_ ROAD DEFECT'),
#  (4.8560208713533174e-05, 'v2_all_events_1_GUARDRAIL END'),
#  (4.842299700870566e-05, 'v1_action_DRIVERLESS-MOVING VEHICLE'),
#  (4.822332555847007e-05, 'v2_vehicle_factors_1_OVER-CORRECTING/OVER-STEERING'),
#  (4.8161284010413625e-05, 'v1_vehicle_factors_3_ UNKNOWN'),
#  (4.780692021890093e-05, 'v2_all_events_3_ PEDESTRIAN'),
#  (4.735901627869518e-05,
#   'nonmotorist_factors_2_ FAILURE TO OBEY TRAFFIC SIGNS, SIGNALS, OR OFFICER'),
#  (4.680421620705413e-05, 'v1_vehicle_factors_2_ UNSAFE BACKING'),
#  (4.673990710671425e-05, 'v1_driver_distracted_CELL PHONE (TALKING)'),
#  (4.66803324279975e-05, 'crash_type_REAR TO SIDE'),
#  (4.663921508229821e-05, 'v1_vehicle_factors_3_ MADE AN IMPROPER TURN'),
#  (4.627194287024898e-05, 'v1_all_events_3_ GUARDRAIL FACE'),
#  (4.603759979093331e-05, 'nonmotorist_factors_3_ IMPROPER CROSSING'),
#  (4.5972237764417814e-05, 'v1_all_events_3_ PEDESTRIAN'),
#  (4.588240644564191e-05, 'v2_all_events_3_ REENTERING ROADWAY'),
#  (4.572383779275038e-05, 'v2_all_events_4_ SLOW/STOPPED VEHICLE'),
#  (4.571829480367187e-05, 'v1_all_events_1_FELL/JUMPED FROM MOTOR VEHICLE'),
#  (4.5250867255543606e-05, 'v1_all_events_2_ CULVERT'),
#  (4.479856362224183e-05, 'v2_all_events_2_ REENTERING ROADWAY'),
#  (4.4786996091867376e-05, 'v2_driver_factors_1_OBSTRUCTED VIEW'),
#  (4.458024992656707e-05, 'hwy_factors_1_NON-ROADWAY WORK'),
#  (4.452705238262218e-05, 'v1_all_events_1_JACKKNIFE'),
#  (4.43175374768001e-05, 'v1_driver_distracted_SMOKING'),
#  (4.431728639151284e-05, 'v1_type_LIFT BOOM'),
#  (4.407638498717546e-05, 'v2_type_STAKE OR RACK'),
#  (4.3866849116105244e-05, 'v2_all_events_1_FELL/JUMPED FROM MOTOR VEHICLE'),
#  (4.339737736170566e-05, 'v1_most_harmful_event_UNKNOWN MOVABLE OBJECT'),
#  (4.322135750341556e-05, 'v1_vehicle_factors_4_ OTHER IMPROPER DRIVING'),
#  (4.2900171942998216e-05,
#   'v1_most_harmful_event_STRUCK BY FALLING, SHIFTING CARGO OR ANYTHING SET IN MOTION'),
#  (4.175076596650957e-05, 'nonmotorist_factors_2_ NOT VISIBLE (DARK CLOTHING)'),
#  (4.106999203350472e-05, 'v1_all_events_4_ RAN OFF ROAD LEFT'),
#  (4.094904453320492e-05, 'lighting_OTHER'),
#  (4.0720480812558506e-05, 'v2_type_REFRIGERATED VAN'),
#  (4.064037892978841e-05, 'nonmotorist_factors_3_ DARTING'),
#  (4.057179360297464e-05, 'v1_type_STAKE OR RACK'),
#  (4.04480105885161e-05, 'hwy_factors_1_SHOULDERS'),
#  (4.0028993786484796e-05, 'factors_roadway_STANDING WATER'),
#  (3.965126453564198e-05, 'v2_all_events_3_ GUARDRAIL FACE'),
#  (3.946395086657561e-05, 'v1_action_OTHER TURNING MOVEMENT'),
#  (3.946332179038832e-05, 'v2_type_FIRE TRUCK'),
#  (3.917465847165519e-05, 'v2_all_events_2_ PEDAL CYCLE'),
#  (3.87745575447129e-05, 'v1_all_events_4_ RAN OFF ROAD RIGHT'),
#  (3.869615207343875e-05, 'v1_most_harmful_event_CROSS MEDIAN'),
#  (3.8571809647791066e-05, 'v2_all_events_2_ CULVERT'),
#  (3.8318981333884834e-05, 'v2_most_harmful_event_CURB'),
#  (3.799294283672702e-05, 'v2_all_events_1_JACKKNIFE'),
#  (3.706112223173009e-05, 'factors_roadway_SNOW'),
#  (3.694150977428388e-05, 'v2_all_events_4_ RAN OFF ROAD LEFT'),
#  (3.6775879199558195e-05,
#   'v2_most_harmful_event_STRUCK BY FALLING, SHIFTING CARGO OR ANYTHING SET IN MOTION'),
#  (3.667166748261201e-05, 'weather_SNOW'),
#  (3.658216835917566e-05,
#   'v1_driver_factors_2_ FELL ASLEEP, FAINTED, FATIGUED, ETC.'),
#  (3.6375517281836306e-05, 'v2_all_events_4_ RAN OFF ROAD RIGHT'),
#  (3.588941834497902e-05, 'factors_roadway_SAND, MUD, DIRT, OIL, GRAVEL'),
#  (3.55652247801624e-05, 'v2_all_events_5_ EMBANKMENT'),
#  (3.5032035714187785e-05, 'v1_vehicle_factors_5_ OTHER IMPROPER DRIVING'),
#  (3.429182813275508e-05, 'v2_driver_distracted_UNKNOWN'),
#  (3.399950322074173e-05, 'v2_driver_factors_1_INATTENTION/DISTRACTED'),
#  (3.34482978194202e-05, 'v2_all_events_4_ CURB'),
#  (3.3440534087308435e-05, 'v2_all_events_2_ UNKNOWN NON-COLLISION'),
#  (3.319946504975436e-05, 'v1_vehicle_factors_1_ROAD DEFECT'),
#  (3.293248399518231e-05, 'v2_all_events_4_ CONCRETE TRAFFIC BARRIER'),
#  (3.2859749215155626e-05, 'v1_vehicle_factors_1_VISIBILITY OBSTRUCTED'),
#  (3.2808491888209345e-05, 'v2_type_HARDTOP'),
#  (3.270101084649095e-05, 'v1_type_COACH'),
#  (3.2586966586452164e-05,
#   'v1_all_events_1_STRUCK BY FALLING, SHIFTING CARGO OR ANYTHING SET IN MOTION'),
#  (3.245579339779335e-05, 'v1_driver_distracted_PERSONAL HYGIENE'),
#  (3.242171148860889e-05, 'v2_vehicle_factors_1_DROVE LEFT OF CENTER'),
#  (3.2181625974287896e-05, 'v1_all_events_5_ EMBANKMENT'),
#  (3.2066675140526765e-05,
#   'v2_all_events_1_STRUCK BY FALLING, SHIFTING CARGO OR ANYTHING SET IN MOTION'),
#  (3.180538814285204e-05, 'v1_all_events_2_ PEDAL CYCLE'),
#  (3.169985407865586e-05,
#   'nonmotorist_factors_3_ FAILURE TO YIELD RIGHT OF WAY'),
#  (3.1500092078653153e-05, 'v2_most_harmful_event_NOT REPORTED'),
#  (3.148590499682622e-05, 'v1_all_events_4_ CONCRETE TRAFFIC BARRIER'),
#  (3.145389435287767e-05, 'v1_type_REFRIGERATED VAN'),
#  (3.136181485863526e-05,
#   'nonmotorist_factors_2_ INATTENTIVE (TALKING, EATING, ETC.)'),
#  (3.130867439032194e-05, 'v1_all_events_2_ UNKNOWN NON-COLLISION'),
#  (3.102638931455648e-05,
#   'v1_most_harmful_event_OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (3.062171115227706e-05, 'v2_all_events_1_OTHER NON-MOTORIST'),
#  (3.0399893864081092e-05, 'v1_all_events_2_ UNKNOWN FIXED OBJECT'),
#  (3.035096445409252e-05, 'v2_vehicle_factors_1_UNSAFE BACKING'),
#  (3.02069569470655e-05, 'v1_most_harmful_event_OTHER POST, POLE OR SUPPORT'),
#  (2.967755573729197e-05, 'v1_most_harmful_event_UNKNOWN NON-COLLISION'),
#  (2.9645279899412985e-05, 'v1_most_harmful_event_OTHER NON-MOTORIST'),
#  (2.9571412019278103e-05, 'v1_all_events_3_ CULVERT'),
#  (2.9545853517484563e-05, 'v2_all_events_4_ REENTERING ROADWAY'),
#  (2.9435783293636345e-05, 'v1_all_events_4_ CURB'),
#  (2.9431507432172185e-05, 'v2_all_events_2_ UNKNOWN FIXED OBJECT'),
#  (2.9385409948553047e-05,
#   'nonmotorist_factors_3_ FAILURE TO OBEY TRAFFIC SIGNS, SIGNALS, OR OFFICER'),
#  (2.9252749094956137e-05, 'v2_most_harmful_event_CROSS MEDIAN/CENTERLINE'),
#  (2.906779502665397e-05, 'v2_all_events_1_IMMERSION'),
#  (2.8985925209889907e-05, 'v2_all_events_4_ NOT REPORTED'),
#  (2.8877879600140698e-05, 'v1_all_events_1_OTHER NON-MOTORIST'),
#  (2.8683825271927124e-05, 'v2_all_events_5_ TREE/SHRUB'),
#  (2.8626829913133685e-05, 'v2_all_events_2_ FELL/JUMPED FROM MOTOR VEHICLE'),
#  (2.847993319231206e-05, 'v2_type_LIFT BOOM'),
#  (2.8171980865790423e-05, 'v1_all_events_4_ FIRE/EXPLOSION'),
#  (2.81351644096305e-05, 'v1_all_events_1_IMMERSION'),
#  (2.8060812878836284e-05, 'v2_all_events_3_ CULVERT'),
#  (2.7818326529805202e-05, 'v1_most_harmful_event_UTILITY POLE'),
#  (2.781488257396522e-05, 'v1_vehicle_factors_4_ OBJECT AVOIDANCE'),
#  (2.7463060202462713e-05, 'hwy_factors_3_ WORK ZONE (CONST. MAINT. UTILITY)'),
#  (2.7282166549186427e-05, 'v1_most_harmful_event_THROWN OR FALLING OBJECT'),
#  (2.7239221937082256e-05, 'animaltype_OTHER ANIMAL'),
#  (2.719624050157028e-05, 'v2_all_events_3_ CROSS MEDIAN'),
#  (2.7114996399156283e-05, 'v1_all_events_4_ DITCH'),
#  (2.69226318744031e-05, 'v1_all_events_4_ REENTERING ROADWAY'),
#  (2.66590375551775e-05, 'v1_all_events_3_ CROSS MEDIAN'),
#  (2.647393534428325e-05, 'v1_most_harmful_event_HIGHWAY TRAFFIC SIGN POST'),
#  (2.6453093614480607e-05, 'v2_type_COACH'),
#  (2.6385256746581812e-05,
#   'hwy_factors_2_ BACKUP DUE TO PRIOR NON-RECURRING INCIDENT'),
#  (2.6157909914514717e-05, 'v2_most_harmful_event_RAN OFF ROAD RIGHT'),
#  (2.593441483397011e-05, 'v2_all_events_4_ DITCH'),
#  (2.5916327945704044e-05, 'v2_most_harmful_event_PEDESTRIAN'),
#  (2.58727365235484e-05,
#   'v2_most_harmful_event_EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (2.571267876775681e-05, 'v2_all_events_4_ PARKED MOTOR VEHICLE'),
#  (2.565448455303461e-05,
#   'v1_vehicle_factors_4_ OVER-CORRECTING/OVER-STEERING'),
#  (2.5456616514584066e-05, 'v1_driver_factors_2_ ILLNESS'),
#  (2.5192192574947886e-05, 'hwy_factors_3_ OTHER HIGHWAY'),
#  (2.503864972576326e-05, 'v1_most_harmful_event_CROSS CENTERLINE'),
#  (2.5034156528247264e-05, 'v1_most_harmful_event_NOT REPORTED'),
#  (2.4914736408897463e-05, 'v1_all_events_5_ TREE/SHRUB'),
#  (2.4754304746602137e-05, 'v2_all_events_1_THROWN OR FALLING OBJECT'),
#  (2.4401911984241647e-05, 'hwy_factors_2_ NON-ROADWAY WORK'),
#  (2.4392516100449567e-05, 'v1_all_events_1_REENTERING ROADWAY'),
#  (2.438946801419315e-05, 'weather_CLOUDY: SEVERE CROSSWINDS'),
#  (2.4297732477266637e-05, 'v1_all_events_3_ FIRE/EXPLOSION'),
#  (2.428039651107244e-05, 'v2_all_events_4_ FIRE/EXPLOSION'),
#  (2.4189361459517877e-05, 'v1_all_events_4_ NOT REPORTED'),
#  (2.397048564059083e-05, 'v2_all_events_1_REENTERING ROADWAY'),
#  (2.3898855676137788e-05, 'v1_all_events_3_ CROSS MEDIAN/CENTERLINE'),
#  (2.3693210677205985e-05, 'v2_all_events_3_ CROSS MEDIAN/CENTERLINE'),
#  (2.3634084377939515e-05, 'v2_all_events_5_ FENCE/WALL'),
#  (2.3317099945216962e-05,
#   'v1_vehicle_factors_3_ DRIVING TOO FAST FOR CONDITIONS'),
#  (2.3201110071465706e-05, 'v1_most_harmful_event_REENTERING ROADWAY'),
#  (2.297922230190132e-05, 'v1_all_events_1_THROWN OR FALLING OBJECT'),
#  (2.295188120459564e-05, 'v1_all_events_4_ UNKNOWN NON-COLLISION'),
#  (2.289218904268384e-05, 'v1_all_events_3_ UNKNOWN NON-COLLISION'),
#  (2.2782078621241936e-05, 'v1_type_ARMORED TRUCK'),
#  (2.259776970497676e-05, 'v1_all_events_4_ PARKED MOTOR VEHICLE'),
#  (2.2289716201832005e-05, 'v2_all_events_3_ FIRE/EXPLOSION'),
#  (2.1907680993249786e-05, 'factors_roadway_MOVING WATER'),
#  (2.17968117638997e-05, 'v2_all_events_3_ UNKNOWN NON-COLLISION'),
#  (2.16169940718913e-05,
#   'v1_vehicle_factors_4_ OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR  AGGRESSIVE MANNER'),
#  (2.1612656729348348e-05, 'v1_most_harmful_event_GUARDRAIL FACE'),
#  (2.130788926303769e-05, 'lighting_DARK - NO ROADWAY LIGHTING'),
#  (2.127566689770571e-05, 'v1_most_harmful_event_CULVERT'),
#  (2.1123117220604453e-05, 'v2_all_events_4_ UNKNOWN NON-COLLISION'),
#  (2.0996981546885695e-05,
#   'nonmotorist_factors_2_ LYING AND/OR ILLEGALLY IN ROADWAY'),
#  (2.0835261250236447e-05, 'v1_driver_distracted_READING'),
#  (2.0823233863860918e-05, 'v2_all_events_2_ JACKKNIFE'),
#  (2.0762010029803443e-05, 'v1_vehicle_factors_5_ ROAD DEFECT'),
#  (2.074033175125444e-05, 'v2_all_events_2_ CROSS CENTERLINE'),
#  (2.072372284947341e-05, 'v1_all_events_4_ OTHER POST, POLE OR SUPPORT'),
#  (2.0652396802764222e-05, 'v2_all_events_4_ OTHER POST, POLE OR SUPPORT'),
#  (2.0549113669726344e-05, 'v2_all_events_1_DITCH'),
#  (2.02945702400752e-05, 'v2_vehicle_factors_2_ HIT AND RUN'),
#  (2.027976545356646e-05, 'v2_all_events_2_ SEPARATION OF UNITS'),
#  (2.0163044109544942e-05, 'v1_all_events_5_ FENCE/WALL'),
#  (1.9859447527596054e-05, 'v2_type_AUTO CARRIER'),
#  (1.9797003214776766e-05, 'v1_all_events_2_ FELL/JUMPED FROM MOTOR VEHICLE'),
#  (1.960707892855889e-05, 'v2_all_events_4_ HIGHWAY TRAFFIC SIGN POST'),
#  (1.9560466518650526e-05, 'v1_vehicle_factors_3_ MECHANICAL DEFECTS'),
#  (1.9317509897226677e-05, 'v2_action_LEAVING PARK POSITION'),
#  (1.916533520687965e-05, 'v2_vehicle_factors_3_ UNSAFE LANE CHANGE'),
#  (1.9041455176205778e-05, 'v2_all_events_1_OTHER TRAFFIC BARRIER'),
#  (1.893175967161234e-05, 'v1_all_events_2_ SEPARATION OF UNITS'),
#  (1.8830646425079732e-05, 'v1_vehicle_factors_5_ RAN OFF ROAD'),
#  (1.8491776593690667e-05, 'v1_all_events_1_OTHER TRAFFIC BARRIER'),
#  (1.8479834947088536e-05, 'v1_all_events_2_ CROSS CENTERLINE'),
#  (1.8469782772305595e-05, 'v1_all_events_2_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  (1.846088770616941e-05,
#   'v1_vehicle_factors_3_ EXCEEDED AUTHORIZED SPEED LIMIT'),
#  (1.843136369214535e-05, 'v1_all_events_2_ JACKKNIFE'),
#  (1.8421439310841752e-05, 'v2_all_events_4_ CULVERT'),
#  (1.808767202428766e-05, 'v2_all_events_2_ TRAFFIC SIGNAL SUPPORT'),
#  (1.8033871435781427e-05, 'v1_all_events_4_ OTHER MOVABLE OBJECT'),
#  (1.7715514999226436e-05, 'v2_most_harmful_event_THROWN OR FALLING OBJECT'),
#  (1.7389496136878426e-05, 'crash_type_SIDESWIPE - OVERTAKING'),
#  (1.7285264640784955e-05, 'v2_vehicle_factors_1_WRONG SIDE OR WRONG WAY'),
#  (1.7218015436742545e-05, 'lighting_DARK - UNKNOWN ROADWAY LIGHTING'),
#  (1.6953350899697894e-05, 'v2_all_events_1_MOTOR VEHICLE IN TRANSPORT'),
#  (1.693920545922963e-05, 'v1_type_MINIBIKE'),
#  (1.6811332571039307e-05, 'v1_all_events_1_DITCH'),
#  (1.6802743318797304e-05, 'v1_driver_factors_3_ DRUG INVOLVEMENT'),
#  (1.663900263826876e-05, 'nonmotorist_factors_2_ WRONG SIDE OF ROAD'),
#  (1.6532324591248398e-05, 'hwy_factors_2_ RUTS, HOLES, BUMPS'),
#  (1.646131962423523e-05,
#   'v2_most_harmful_event_WORK ZONE MAINTENANCE EQUIPMENT'),
#  (1.6441891241944676e-05, 'v2_type_LOG'),
#  (1.6396983419724642e-05, 'v2_all_events_4_ OTHER MOVABLE OBJECT'),
#  (1.637648551388703e-05, 'v2_all_events_2_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  (1.629939534246056e-05, 'v2_most_harmful_event_CROSS MEDIAN'),
#  (1.6280510508108358e-05, 'v1_all_events_4_ HIGHWAY TRAFFIC SIGN POST'),
#  (1.609886198642492e-05, 'v1_type_FIRE TRUCK'),
#  (1.605480026015009e-05, 'v2_type_GOLF CART'),
#  (1.603141240241742e-05,
#   'v1_most_harmful_event_WORK ZONE MAINTENANCE EQUIPMENT'),
#  (1.5904409898286082e-05, 'v1_most_harmful_event_JACKKNIFE'),
#  (1.5837554679077613e-05, 'v1_type_AUTO CARRIER'),
#  (1.5728421353545397e-05, 'v2_all_events_1_TRAFFIC SIGNAL SUPPORT'),
#  (1.5601657796998175e-05, 'v1_type_GOLF CART'),
#  (1.536348016392217e-05, 'v1_all_events_2_ TRAFFIC SIGNAL SUPPORT'),
#  (1.53374297421883e-05, 'v2_type_MULTI-WHEEL'),
#  (1.5337127280516302e-05, 'v2_driver_factors_2_ DRUG INVOLVEMENT'),
#  (1.5241411542169336e-05, 'v2_all_events_2_ MAILBOX'),
#  (1.5170667886420205e-05, 'v2_most_harmful_event_TREE/SHRUB'),
#  (1.5096481687518501e-05,
#   'nonmotorist_factors_3_ NOT VISIBLE (DARK CLOTHING)'),
#  (1.506832291818889e-05, 'v2_all_events_3_ GUARDRAIL END'),
#  (1.5063792710865822e-05, 'v1_all_events_4_ CULVERT'),
#  (1.498251662035083e-05,
#   'nonmotorist_factors_3_ INATTENTIVE (TALKING, EATING, ETC.)'),
#  (1.4929706338203607e-05, 'v1_most_harmful_event_TRAFFIC SIGNAL SUPPORT'),
#  (1.4724399289025861e-05, 'v1_all_events_2_ MAILBOX'),
#  (1.4602593766265587e-05, 'v1_all_events_1_MOTOR VEHICLE IN TRANSPORT'),
#  (1.4511071569462888e-05, 'v1_all_events_5_ MEDIAN BARRIER'),
#  (1.446907865991503e-05, 'v2_type_LOWBOY OR LOWBED'),
#  (1.431214072233082e-05, 'v1_all_events_3_ CROSS CENTERLINE'),
#  (1.4290427293628564e-05, 'factors_roadway_OTHER'),
#  (1.4289956071148552e-05, 'v2_all_events_1_OTHER ANIMAL'),
#  (1.4265888007361442e-05, 'hwy_factors_3_ BACKUP DUE TO REGULAR CONGESTION'),
#  (1.4195590703022268e-05, 'v2_all_events_3_ CROSS CENTERLINE'),
#  (1.4152813124914227e-05, 'v2_all_events_4_ GUARDRAIL FACE'),
#  (1.4006759623000406e-05, 'hwy_factors_2_ BACKUP DUE TO PRIOR CRASH'),
#  (1.3914256910527712e-05, 'hwy_factors_2_ OTHER ENVIRONMENTAL'),
#  (1.385185381304359e-05, 'v1_all_events_2_ BRIDGE RAIL'),
#  (1.3732117376968107e-05, 'hwy_factors_3_ WET, ICY, SNOW, SLUSH'),
#  (1.3707827790440064e-05, 'v2_most_harmful_event_RAN OFF ROAD LEFT'),
#  (1.3590405885112411e-05, 'v2_most_harmful_event_OTHER POST, POLE OR SUPPORT'),
#  (1.3418446942175966e-05, 'v1_all_events_3_ IMPACT ATTENUATOR/CRASH CUSHION'),
#  (1.3391169414027899e-05,
#   'v1_vehicle_factors_4_ FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (1.3194433768147987e-05, 'v1_type_BEVERAGE TRUCK'),
#  (1.3172455598826178e-05, 'v2_all_events_2_ BRIDGE RAIL'),
#  (1.3123304458319915e-05, 'v1_all_events_1_UNKNOWN FIXED OBJECT'),
#  (1.3118752040205744e-05, 'v2_driver_factors_1_PHYSICAL IMPAIRMENT'),
#  (1.3057915858110178e-05, 'v1_vehicle_factors_4_ UNKNOWN'),
#  (1.2998839580123306e-05, 'v1_all_events_3_ GUARDRAIL END'),
#  (1.2981396711020962e-05, 'v1_vehicle_factors_5_ HIT AND RUN'),
#  (1.2949782278750762e-05, 'v2_all_events_3_ FELL/JUMPED FROM MOTOR VEHICLE'),
#  (1.2942909616784717e-05, 'v1_all_events_1_TRAFFIC SIGNAL SUPPORT'),
#  (1.2797806801321924e-05, 'v2_all_events_3_ IMPACT ATTENUATOR/CRASH CUSHION'),
#  (1.2690689954796392e-05, 'v1_vehicle_factors_2_ OTHER'),
#  (1.2537507291095104e-05,
#   'v2_most_harmful_event_FELL/JUMPED FROM MOTOR VEHICLE'),
#  (1.240929973214913e-05, 'hwy_factors_2_ GLARE'),
#  (1.2404425428450482e-05, 'v2_vehicle_factors_2_ OTHER IMPROPER DRIVING'),
#  (1.2381846508508229e-05, 'v2_vehicle_factors_1_VISIBILITY OBSTRUCTED'),
#  (1.2376834622977865e-05, 'animaltype_DOG/COYOTE'),
#  (1.2375364770241088e-05, 'v1_all_events_5_ FIRE/EXPLOSION'),
#  (1.2317269589325308e-05, 'v1_most_harmful_event_SEPARATION OF UNITS'),
#  (1.2314432710231635e-05, 'hwy_factors_3_ BACKUP DUE TO PRIOR CRASH'),
#  (1.2296244383083757e-05, 'v1_most_harmful_event_IMMERSION'),
#  (1.2294741970984833e-05, 'v2_type_FLATRACK'),
#  (1.2210521722033161e-05, 'animaltype_BURRO'),
#  (1.218867996473275e-05, 'v1_all_events_4_ GUARDRAIL FACE'),
#  (1.2179443496925441e-05, 'v2_type_BEVERAGE TRUCK'),
#  (1.2160409195638693e-05, 'v2_most_harmful_event_UNKNOWN NON-COLLISION'),
#  (1.2135186729650229e-05, 'v1_all_events_1_BURRO'),
#  (1.2121019061538841e-05, 'v1_type_MINICYCLE'),
#  (1.1884687743337396e-05, 'v1_all_events_1_OTHER ANIMAL'),
#  (1.1701212212242106e-05, 'v2_all_events_5_ MEDIAN BARRIER'),
#  (1.1640107905365648e-05, 'hwy_factors_2_ INACTIVE WORK ZONE'),
#  (1.163669202197011e-05, 'v1_type_LOG'),
#  (1.152671796348326e-05, 'v1_driver_factors_2_ OBSTRUCTED VIEW'),
#  (1.1392002774610898e-05, 'v2_all_events_1_BRIDGE RAIL'),
#  (1.1180518378415693e-05, 'v1_vehicle_factors_3_ VISIBILITY OBSTRUCTED'),
#  (1.1115403085817638e-05, 'v2_most_harmful_event_FIRE/EXPLOSION'),
#  (1.1004239306441986e-05, 'v1_all_events_1_OVERHEAD SIGN SUPPORT'),
#  (1.0827944701041419e-05, 'v1_most_harmful_event_OTHER TRAFFIC BARRIER'),
#  (1.08242782849042e-05, 'v2_all_events_5_ FIRE/EXPLOSION'),
#  (1.0691409579763864e-05, 'v2_most_harmful_event_OTHER ANIMAL'),
#  (1.068415260513364e-05, 'v1_vehicle_factors_3_ UNSAFE BACKING'),
#  (1.0668392268660254e-05, 'weather_CLOUDY: BLOWING SAND, SOIL, DIRT, SNOW'),
#  (1.0485189715035045e-05, 'v1_vehicle_factors_5_ DROVE LEFT OF CENTER'),
#  (1.0482550283151275e-05, 'weather_FOG, SMOG, SMOKE: RAIN'),
#  (1.0482440696415366e-05, 'v1_all_events_1_DOG/COYOTE'),
#  (1.0313066027914069e-05, 'v1_all_events_2_ BURRO'),
#  (1.0225923600618463e-05, 'v2_all_events_1_BURRO'),
#  (1.0221607533813338e-05, 'v2_all_events_1_DOG/COYOTE'),
#  (1.0162263601520429e-05, 'hwy_factors_2_ ROAD OBSTRUCTION'),
#  (1.0119601386007e-05, 'v1_type_UNKNOWN AT TIME OF CONVERSION'),
#  (1.0071955475872108e-05, 'v2_all_events_1_UNKNOWN FIXED OBJECT'),
#  (1.0054764027571357e-05, 'v1_all_events_3_ FELL/JUMPED FROM MOTOR VEHICLE'),
#  (9.845253242080028e-06, 'v1_all_events_4_ PEDESTRIAN'),
#  (9.833848998449313e-06, 'v1_type_MOTORIZED CART'),
#  (9.83263015243325e-06,
#   'v2_most_harmful_event_OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (9.729276357870956e-06, 'v2_all_events_2_ OTHER TRAFFIC BARRIER'),
#  (9.706009756423247e-06, 'v2_driver_distracted_RADIO/CD PLAYER'),
#  (9.591634208962618e-06, 'v2_all_events_1_OVERHEAD SIGN SUPPORT'),
#  (9.570188788961553e-06, 'v1_all_events_5_ LIGHT/LUMINARY SUPPORT'),
#  (9.43762275141924e-06, 'v2_all_events_4_ PEDESTRIAN'),
#  (9.388383937629011e-06, 'weather_CLOUDY: SNOW'),
#  (9.35606178895549e-06, 'v2_vehicle_factors_2_ RAN OFF ROAD'),
#  (9.117568015813685e-06, 'v2_most_harmful_event_CROSS CENTERLINE'),
#  (9.04460826139675e-06, 'v2_all_events_5_ LIGHT/LUMINARY SUPPORT'),
#  (8.896887075412787e-06, 'v1_type_UNKNOWN'),
#  (8.879879786847243e-06, 'v1_all_events_2_ OTHER TRAFFIC BARRIER'),
#  (8.842581434490321e-06, 'v1_all_events_3_ SEPARATION OF UNITS'),
#  (8.812988636960793e-06, 'v2_all_events_2_ BURRO'),
#  (8.761078409584933e-06, 'v2_most_harmful_event_LIGHT/LUMINARY SUPPORT'),
#  (8.685743908246966e-06, 'v1_vehicle_factors_5_ OBJECT AVOIDANCE'),
#  (8.618454209103488e-06, 'v2_all_events_1_DEER'),
#  (8.610202273661037e-06, 'v1_all_events_1_DEER'),
#  (8.58754584091435e-06, 'v1_type_FLATRACK'),
#  (8.44748589866312e-06, 'weather_CLOUDY: OTHER'),
#  (8.42098154541245e-06, 'v2_driver_distracted_OTHER'),
#  (8.328935488892355e-06, 'v1_all_events_3_ OVERHEAD SIGN SUPPORT'),
#  (8.245002795978765e-06, 'v2_type_MOTORIZED SCOOTER'),
#  (8.134709592686117e-06, 'v2_all_events_5_ CONCRETE TRAFFIC BARRIER'),
#  (8.11763586855094e-06, 'v2_all_events_2_ OVERHEAD SIGN SUPPORT'),
#  (8.09122501444853e-06, 'v1_all_events_4_ UTILITY POLE'),
#  (8.064740112478047e-06, 'v1_all_events_3_ UNKNOWN FIXED OBJECT'),
#  (8.006617973476268e-06, 'v2_most_harmful_event_IMMERSION'),
#  (7.912883174589247e-06, 'v1_all_events_4_ OTHER TRAFFIC BARRIER'),
#  (7.885388521504233e-06, 'v1_type_MOTORIZED SCOOTER'),
#  (7.745650798712231e-06, 'v1_all_events_2_ OVERHEAD SIGN SUPPORT'),
#  (7.725889808018049e-06, 'v1_all_events_1_CULVERT'),
#  (7.695090459900704e-06,
#   'v1_all_events_5_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (7.686056808324823e-06, 'v1_all_events_1_BRIDGE RAIL'),
#  (7.649815421075892e-06, 'v1_vehicle_factors_3_ WRONG SIDE OR WRONG WAY'),
#  (7.456217609892064e-06, 'v1_all_events_5_ CONCRETE TRAFFIC BARRIER'),
#  (7.4336303467159004e-06, 'v1_all_events_3_ OTHER NON-COLLISION'),
#  (7.40756691351103e-06, 'v2_all_events_3_ OVERHEAD SIGN SUPPORT'),
#  (7.39953083462223e-06, 'v2_all_events_4_ OTHER NON-COLLISION'),
#  (7.358314229715395e-06, 'v1_all_events_1_CABLE BARRIER'),
#  (7.305079149816897e-06, 'v2_type_ROADSTER'),
#  (7.303813764575853e-06, 'v2_most_harmful_event_SEPARATION OF UNITS'),
#  (7.256534428930061e-06, 'v2_all_events_5_ PARKED MOTOR VEHICLE'),
#  (7.216560977224104e-06, 'v2_type_ARMORED TRUCK'),
#  (7.215859964010296e-06, 'v1_action_U-TURN'),
#  (7.196060451479267e-06, 'v2_all_events_4_ UTILITY POLE'),
#  (7.1024195591617565e-06, 'hwy_factors_2_ DEBRIS'),
#  (7.0915908703140715e-06,
#   'v2_all_events_5_ OTHER FIXED OBJECTS (BUILDING, TUNNEL, ETC.)'),
#  (7.0871510433615095e-06, 'v2_all_events_3_ SEPARATION OF UNITS'),
#  (7.0505289272761294e-06, 'v1_all_events_2_ CABLE BARRIER'),
#  (7.020267758360394e-06, 'v2_vehicle_factors_3_ ROAD DEFECT'),
#  (6.982893912748658e-06, 'v2_all_events_5_ SLOW/STOPPED VEHICLE'),
#  (6.772504908158475e-06, 'v2_all_events_5_ HIGHWAY TRAFFIC SIGN POST'),
#  (6.7476714043167164e-06, 'v1_most_harmful_event_DOG/COYOTE'),
#  (6.726318181162206e-06, 'v1_all_events_3_ BRIDGE PIER OR ABUTMENT'),
#  (6.691154890914432e-06, 'v2_all_events_1_CABLE BARRIER'),
#  (6.662946075785853e-06, 'v2_driver_distracted_OTHER INSIDE THE VEHICLE'),
#  (6.525615046702307e-06, 'v2_most_harmful_event_REENTERING ROADWAY'),
#  (6.516500498523457e-06, 'v2_all_events_3_ BRIDGE PIER OR ABUTMENT'),
#  (6.429712279747568e-06, 'v2_all_events_3_ UNKNOWN FIXED OBJECT'),
#  (6.3889711665360515e-06, 'v1_most_harmful_event_CABLE BARRIER'),
#  (6.220666011153144e-06, 'v1_all_events_5_ PARKED MOTOR VEHICLE'),
#  (6.192219685719645e-06, 'hwy_factors_3_ OTHER ENVIRONMENTAL'),
#  (6.139842542061855e-06, 'v2_all_events_3_ BRIDGE RAIL'),
#  (6.010746628360555e-06, 'v2_all_events_3_ OTHER NON-COLLISION'),
#  (5.991476505164557e-06, 'nonmotorist_factors_2_ OTHER'),
#  (5.9653691817920304e-06, 'v1_all_events_5_ DITCH'),
#  (5.9287952635240315e-06, 'v1_action_LANE CHANGE'),
#  (5.9242803263902715e-06, 'v1_all_events_5_ SLOW/STOPPED VEHICLE'),
#  (5.90849227198567e-06, 'v2_most_harmful_event_DITCH'),
#  (5.906822393052996e-06,
#   'v2_vehicle_factors_2_ OVER-CORRECTING/OVER-STEERING'),
#  (5.8510768916501206e-06, 'v2_vehicle_factors_2_ OBJECT AVOIDANCE'),
#  (5.815364018056358e-06, 'v1_all_events_1_RAILWAY VEHICLE'),
#  (5.815078319948298e-06, 'v1_all_events_4_ OTHER NON-COLLISION'),
#  (5.8049850286129975e-06, 'nonmotorist_factors_3_ WRONG SIDE OF ROAD'),
#  (5.7899999423489094e-06, 'v2_action_TRAVELING WRONG WAY'),
#  (5.73019758086938e-06, 'v2_type_MOTORIZED CART'),
#  (5.729294547467298e-06, 'v2_all_events_4_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  (5.649149260148609e-06, 'v2_all_events_5_ DITCH'),
#  (5.606063158733312e-06, 'animaltype_DEER'),
#  (5.599458921271654e-06, 'v2_all_events_3_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  (5.563082565218892e-06, 'weather_RAIN: BLOWING SAND, SOIL, DIRT, SNOW'),
#  (5.538879018070768e-06, 'weather_RAIN: OTHER'),
#  (5.4938046850448485e-06, 'hwy_factors_2_ VISUAL OBSTRUCTION(S)'),
#  (5.45782225792142e-06, 'v1_vehicle_factors_4_ MADE AN IMPROPER TURN'),
#  (5.4385552126869425e-06, 'v2_all_events_1_CULVERT'),
#  (5.395601289401195e-06, 'v2_all_events_2_ CABLE BARRIER'),
#  (5.3561134188393745e-06, 'v1_all_events_5_ CULVERT'),
#  (5.318421013109024e-06, 'v1_most_harmful_event_GUARDRAIL END'),
#  (5.317683784666955e-06, 'v1_driver_factors_3_ HAD BEEN DRINKING'),
#  (5.304593785743728e-06, 'v2_most_harmful_event_EMBANKMENT'),
#  (5.176056761834198e-06, 'v1_all_events_5_ HIGHWAY TRAFFIC SIGN POST'),
#  (5.1616360441823075e-06, 'v1_all_events_5_ NOT REPORTED'),
#  (5.158080260343439e-06, 'weather_CLOUDY: FOG, SMOG, SMOKE'),
#  (5.138279868280146e-06, 'v2_most_harmful_event_JACKKNIFE'),
#  (5.135628609516234e-06, 'v1_most_harmful_event_OTHER ANIMAL'),
#  (5.083446404475654e-06,
#   'v1_all_events_2_ EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (5.0628886226606136e-06, 'v1_all_events_4_ UNKNOWN FIXED OBJECT'),
#  (5.0625573216035475e-06, 'hwy_factors_1_NONE '),
#  (5.056253649643144e-06, 'v1_all_events_1_BRIDGE OVERHEAD STRUCTURE'),
#  (5.020363111190266e-06,
#   'nonmotorist_factors_3_ LYING AND/OR ILLEGALLY IN ROADWAY'),
#  (4.99543832701771e-06, 'v1_most_harmful_event_UNKNOWN FIXED OBJECT'),
#  (4.988834311843961e-06, 'v1_all_events_3_ TRAFFIC SIGNAL SUPPORT'),
#  (4.964467027835154e-06, 'v1_type_WELL DRILLER'),
#  (4.9563653240488404e-06, 'v2_all_events_5_ CULVERT'),
#  (4.9173085475531355e-06, 'v2_all_events_5_ REENTERING ROADWAY'),
#  (4.861018005591034e-06, 'v2_vehicle_factors_3_ OBJECT AVOIDANCE'),
#  (4.85886457196927e-06, 'v1_most_harmful_event_BRIDGE PIER OR ABUTMENT'),
#  (4.816242010421322e-06, 'v1_type_HOPPER (BOTTOM DUMP)'),
#  (4.8076235683877694e-06, 'v2_all_events_5_ NOT REPORTED'),
#  (4.8046623996224e-06, 'v1_vehicle_factors_3_ FOLLOWED TOO CLOSELY'),
#  (4.769256658912829e-06, 'v2_all_events_1_RAILWAY VEHICLE'),
#  (4.767337500885399e-06, 'v1_vehicle_factors_2_ DRIVERLESS VEHICLE'),
#  (4.719583309684489e-06, 'v2_all_events_1_RAN OFF ROAD'),
#  (4.689090045890958e-06,
#   'v2_driver_distracted_EXTERNAL DISTRACTION (OUTSIDE THE VEHICLE)'),
#  (4.659658772048968e-06, 'v2_most_harmful_event_UTILITY POLE'),
#  (4.653766767835725e-06, 'v2_type_LUNCH WAGON'),
#  (4.565515805793917e-06, 'hwy_factors_2_ WORN TRAFFIC SURFACE'),
#  (4.5392388922150995e-06, 'v1_all_events_3_ BRIDGE RAIL'),
#  (4.501476574759275e-06, 'v2_all_events_3_ TRAFFIC SIGNAL SUPPORT'),
#  (4.467836337429897e-06, 'weather_NOT DESIGN FOR THIS NUMBER'),
#  (4.440787370142252e-06, 'v1_most_harmful_event_BURRO'),
#  (4.438390705756385e-06, 'v2_all_events_1_BRIDGE OVERHEAD STRUCTURE'),
#  (4.4018474987992265e-06, 'v1_all_events_3_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  (4.336148344079922e-06, 'v1_all_events_4_ JACKKNIFE'),
#  (4.294659541376969e-06, 'v1_type_LUNCH WAGON'),
#  (4.245878135174761e-06, 'v2_type_GLASS RACK'),
#  (4.2110960631196654e-06, 'v2_vehicle_factors_1_ROAD DEFECT'),
#  (4.171704624413725e-06, 'v2_all_events_4_ CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (4.140216957615163e-06, 'factors_roadway_SLUSH'),
#  (4.14015280083958e-06, 'v2_all_events_4_ UNKNOWN FIXED OBJECT'),
#  (4.134282469801967e-06, 'weather_RAIN: SEVERE CROSSWINDS'),
#  (4.120566339280419e-06, 'hwy_factors_2_ ACTIVE WORK ZONE'),
#  (4.116550143005062e-06, 'v2_all_events_4_ OTHER TRAFFIC BARRIER'),
#  (4.061990527498972e-06, 'v2_most_harmful_event_TRAFFIC SIGNAL SUPPORT'),
#  (4.059683934419156e-06, 'v1_type_TOURING CAR'),
#  (4.0448131164854426e-06, 'v1_most_harmful_event_DOWNHILL RUNAWAY'),
#  (4.027462335133518e-06, 'v1_all_events_4_ CARGO/EQUIPMENT LOSS OR SHIFT'),
#  (4.023864861694738e-06, 'v2_all_events_4_ GUARDRAIL END'),
#  (4.008182946824863e-06, 'v2_vehicle_factors_3_ UNKNOWN'),
#  (4.006948412654848e-06, 'v2_all_events_3_ UNKNOWN MOVABLE OBJECT'),
#  (4.000562627130285e-06, 'v2_all_events_2_ BRIDGE OVERHEAD STRUCTURE'),
#  (3.870997728730451e-06, 'v1_all_events_5_ RAN OFF ROAD RIGHT'),
#  (3.860024217662033e-06, 'v1_all_events_3_ RAILWAY VEHICLE'),
#  (3.843656363109645e-06,
#   'v2_all_events_3_ EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (3.7861870507782574e-06, 'v1_type_HEARSE'),
#  (3.7826654792673143e-06, 'v2_most_harmful_event_PEDAL CYCLE'),
#  (3.773221950952162e-06, 'v2_all_events_2_ BRIDGE PIER OR ABUTMENT'),
#  (3.7119295733092267e-06, 'v1_most_harmful_event_OVERHEAD SIGN SUPPORT'),
#  (3.691654927752889e-06, 'v1_all_events_2_ BRIDGE OVERHEAD STRUCTURE'),
#  (3.6811007218544193e-06, 'v1_all_events_1_RAN OFF ROAD'),
#  (3.6732381125959754e-06, 'v1_type_ROADSTER'),
#  (3.6671769875570113e-06, 'v1_all_events_3_ UNKNOWN MOVABLE OBJECT'),
#  (3.6548397082394606e-06,
#   'v2_all_events_2_ EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (3.6274628444911714e-06, 'v1_type_GLASS RACK'),
#  (3.559609253353496e-06, 'v2_all_events_5_ UTILITY POLE'),
#  (3.5494183851299174e-06, 'v1_all_events_1_HORSE'),
#  (3.492628195765157e-06, 'v2_all_events_1_CATTLE'),
#  (3.490210266938388e-06,
#   'v2_vehicle_factors_2_ FAILURE TO KEEP IN PROPER LANE OR RUNNING OFF ROAD'),
#  (3.456955286170794e-06, 'v1_most_harmful_event_DEER'),
#  (3.443139889250216e-06, 'v1_vehicle_factors_4_ OTHER'),
#  (3.429017893171703e-06,
#   'v2_vehicle_factors_2_ DISREGARDED TRAFFIC SIGNS, SIGNALS, ROAD MARKINGS'),
#  (3.4279246094615873e-06, 'v2_all_events_3_ RAILWAY VEHICLE'),
#  (3.344143248210198e-06, 'v2_all_events_3_ JACKKNIFE'),
#  (3.2300060946756293e-06,
#   'hwy_factors_3_ BACKUP DUE TO PRIOR NON-RECURRING INCIDENT'),
#  (3.187036223255069e-06, 'v2_most_harmful_event_OTHER NON-MOTORIST'),
#  (3.1781893263079053e-06, 'v1_all_events_2_ IMMERSION'),
#  (3.157847696418606e-06, 'v1_vehicle_factors_4_ DRIVERLESS VEHICLE'),
#  (3.1577813303437365e-06, 'v2_all_events_1_HORSE'),
#  (3.127347252335102e-06,
#   'v1_all_events_3_ EQUIPMENT FAILURE (BLOWN TIRE, BRAKE FAILURE, ETC.)'),
#  (3.0845981198812558e-06, 'v2_driver_distracted_CELL PHONE (TEXTING)'),
#  (3.058473295345639e-06, 'v2_most_harmful_event_UNKNOWN MOVABLE OBJECT'),
#  (3.003280611370138e-06, 'v1_all_events_1_MECHANICAL DEFECTS'),
#  (2.9819799254707736e-06, 'v2_type_WELL DRILLER'),
#  (2.9755446224174606e-06, 'weather_BLOWING SAND, SOIL, DIRT, SNOW: OTHER'),
#  (2.962552911860737e-06,
#   'v2_vehicle_factors_2_ DRIVING TOO FAST FOR CONDITIONS'),
#  (2.9320642757137413e-06, 'v1_type_GRAIN'),
#  (2.9117427301516598e-06, 'v1_all_events_5_ CROSS MEDIAN'),
#  (2.8988168991769643e-06, 'v1_all_events_4_ IMMERSION'),
#  (2.8871456919847233e-06, 'weather_BLOWING SAND, DIRT, SOIL, SNOW; '),
#  (2.8374971962955314e-06, 'v2_action_RACING'),
#  (2.796823255991154e-06, 'v2_all_events_1_DOWNHILL RUNAWAY'),
#  (2.7619684712883377e-06, 'v1_type_LOWBOY OR LOWBED'),
#  (2.760019699454265e-06, 'v2_most_harmful_event_DOWNHILL RUNAWAY'),
#  (2.756303672896535e-06, 'v2_all_events_5_ RAN OFF ROAD RIGHT'),
#  (2.7401162177443553e-06, 'crash_type_SIDESWIPE - MEETING'),
#  (2.7365157591994996e-06, 'v1_all_events_4_ GUARDRAIL END'),
#  (2.7319935525680925e-06, 'v1_all_events_4_ WORK ZONE MAINTENANCE EQUIPMENT'),
#  ...]
