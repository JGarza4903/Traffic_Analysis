# %%
import pandas as pd

# %%
clark_co_df = pd.read_csv('../Resources/FilteredCrashData.csv')
clark_co_df
# Out:
# C:\Users\jorda\AppData\Local\Temp\ipykernel_21644\322049444.py:1: DtypeWarning: Columns (22,32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   clark_co_df = pd.read_csv('../Resources/FilteredCrashData.csv')
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N
# 1       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573
# 2       2016/01/03 02:29:59+00        2016   2:30:00 AM             IR15S
# 3       2016/01/03 00:00:00+00        2016   9:22:00 PM      S DURANGO DR
# 4       2016/01/06 06:01:59+00        2016   6:02:00 AM    W ALEXANDER RD
# ...                        ...         ...          ...               ...
# 178453  2020/12/31 13:24:00+00        2020   1:24:00 PM      E RUSSELL RD
# 178454  2020/12/29 20:03:59+00        2020   8:04:00 PM  S LAS VEGAS BLVD
# 178455  2020/12/31 01:24:00+00        2020   1:24:00 AM     W FLAMINGO RD
# 178456  2020/12/28 17:19:59+00        2020   5:20:00 PM   WARM SPRINGS RD
# 178457  2020/12/30 21:53:00+00        2020   9:53:00 PM     MEL TORME WAY
#
#         Distance  ...                     Lighting  \
# 0            1.0  ...                     DAYLIGHT
# 1           30.0  ...                     DAYLIGHT
# 2          200.0  ...         DARK - SPOT LIGHTING
# 3          147.0  ...  DARK - CONTINUOUS LIGHTING
# 4          100.0  ...  DARK - CONTINUOUS LIGHTING
# ...          ...  ...                          ...
# 178453     412.0  ...                     DAYLIGHT
# 178454     783.0  ...  DARK - CONTINUOUS LIGHTING
# 178455     240.0  ...  DARK - CONTINUOUS LIGHTING
# 178456       5.0  ...  DARK - CONTINUOUS LIGHTING
# 178457      10.0  ...         DARK - SPOT LIGHTING
#
#                               HWY_Factors Agency  Accident_Rec_Num  \
# 0                                    NONE    NHP         2224407.0
# 1                   WET, ICY, SNOW, SLUSH    NHP         2224394.0
# 2                                    NONE    NHP         2215025.0
# 3                                    NONE  LVMPD         2221432.0
# 4                                    NONE   NLPD         2215818.0
# ...                                   ...    ...               ...
# 178453  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD         3145910.0
# 178454                               NONE  LVMPD         3145748.0
# 178455                               NONE  LVMPD         3146377.0
# 178456                               NONE   HEPD         3223422.0
# 178457                               NONE    NHP         3147538.0
#
#         Pedalcyclist Pedestrian Motorcyclist AnimalType  CrashDateTimeUTC  \
# 0                NaN        NaN          NaN        NaN               NaN
# 1                NaN        NaN          NaN        NaN               NaN
# 2                NaN        NaN          NaN        NaN               NaN
# 3                NaN        YES          NaN        NaN               NaN
# 4                NaN        YES          NaN        NaN               NaN
# ...              ...        ...          ...        ...               ...
# 178453           NaN        NaN          NaN        NaN               NaN
# 178454           NaN        NaN          NaN        NaN               NaN
# 178455           NaN        NaN          NaN        NaN               NaN
# 178456           NaN        NaN          NaN        NaN               NaN
# 178457           NaN        NaN          NaN        NaN               NaN
#
#                                       GlobalID
# 0       {0087FD29-7934-4ECF-8F61-F2CB6A3C77F2}
# 1       {010D62A2-A007-45DF-A118-4C4F4257FBB4}
# 2       {01B574F5-18E1-4129-B2CE-7E562525D3B7}
# 3       {0200F72F-52F9-4E26-BA4B-76C3387E088F}
# 4       {0218E945-CE8F-4EF8-A93E-DA08E0AB1655}
# ...                                        ...
# 178453  {FB130F71-4945-4D88-8294-818A65FCD6A1}
# 178454  {FB209CA0-5222-4FCA-9E3E-1859B25EFA42}
# 178455  {FDBCD936-FA23-4323-A5FA-8459D28BFE28}
# 178456  {FDE7861D-219D-4A77-B116-4EFAE25A3A80}
# 178457  {FF736BF8-3236-45C8-9B1E-8066FE11359F}
#
# [178458 rows x 52 columns]

# %%
clark_co_df.isnull().sum()
# Out:
# X                             0
# Y                             0
# OBJECTID                      0
# Crash_Severity                0
# County                        0
# Crash_Date                    0
# Crash_Year                    0
# Crash_Time                    0
# Primary_Street                0
# Distance                  51609
# Dir                           0
# Secondary_Street              1
# Weather                     553
# Fatalities               177498
# Injured                   97385
# Property_Damage_Only      81657
# Injury_Type               96955
# Crash_Type                  166
# Total_Vehicles                0
# V1_Type                    7687
# V1_Dir                    21503
# V1_Driver_Age             41376
# V1_Lane_Num               54219
# V1_Action                   387
# V1_Driver_Factors         15428
# V1_Driver_Distracted     171201
# V1_Vehicle_Factors        14986
# V1_Most_Harmful_Event     90618
# V1_All_Events             89686
# V2_Type                   23791
# V2_Dir                    25331
# V2_Driver_Age             51460
# V2_Lane_Num               66497
# V2_Action                 23031
# V2_Driver_Factors         29362
# V2_Driver_Distracted     178360
# V2_Vehicle_Factors       156450
# V2_Most_Harmful_Event     98528
# V2_All_Events            145917
# First_Harmful_Event       93400
# Nonmotorist_Factors      174664
# Factors_Roadway           19446
# Lighting                  24764
# HWY_Factors               25691
# Agency                      236
# Accident_Rec_Num             85
# Pedalcyclist             176737
# Pedestrian               174594
# Motorcyclist             174754
# AnimalType               177567
# CrashDateTimeUTC         178458
# GlobalID                      0
# dtype: int64

# %%
clark_co_df.iloc[:,8:].isnull().sum()
# Out:
# Primary_Street                0
# Distance                  51609
# Dir                           0
# Secondary_Street              1
# Weather                     553
# Fatalities               177498
# Injured                   97385
# Property_Damage_Only      81657
# Injury_Type               96955
# Crash_Type                  166
# Total_Vehicles                0
# V1_Type                    7687
# V1_Dir                    21503
# V1_Driver_Age             41376
# V1_Lane_Num               54219
# V1_Action                   387
# V1_Driver_Factors         15428
# V1_Driver_Distracted     171201
# V1_Vehicle_Factors        14986
# V1_Most_Harmful_Event     90618
# V1_All_Events             89686
# V2_Type                   23791
# V2_Dir                    25331
# V2_Driver_Age             51460
# V2_Lane_Num               66497
# V2_Action                 23031
# V2_Driver_Factors         29362
# V2_Driver_Distracted     178360
# V2_Vehicle_Factors       156450
# V2_Most_Harmful_Event     98528
# V2_All_Events            145917
# First_Harmful_Event       93400
# Nonmotorist_Factors      174664
# Factors_Roadway           19446
# Lighting                  24764
# HWY_Factors               25691
# Agency                      236
# Accident_Rec_Num             85
# Pedalcyclist             176737
# Pedestrian               174594
# Motorcyclist             174754
# AnimalType               177567
# CrashDateTimeUTC         178458
# GlobalID                      0
# dtype: int64

# %%
clark_co_df.iloc[:,24:].isnull().sum()
# Out:
# V1_Driver_Factors         15428
# V1_Driver_Distracted     171201
# V1_Vehicle_Factors        14986
# V1_Most_Harmful_Event     90618
# V1_All_Events             89686
# V2_Type                   23791
# V2_Dir                    25331
# V2_Driver_Age             51460
# V2_Lane_Num               66497
# V2_Action                 23031
# V2_Driver_Factors         29362
# V2_Driver_Distracted     178360
# V2_Vehicle_Factors       156450
# V2_Most_Harmful_Event     98528
# V2_All_Events            145917
# First_Harmful_Event       93400
# Nonmotorist_Factors      174664
# Factors_Roadway           19446
# Lighting                  24764
# HWY_Factors               25691
# Agency                      236
# Accident_Rec_Num             85
# Pedalcyclist             176737
# Pedestrian               174594
# Motorcyclist             174754
# AnimalType               177567
# CrashDateTimeUTC         178458
# GlobalID                      0
# dtype: int64

# %%
# Drop Global UTC-Time column
clark_co_df.drop(columns = ['CrashDateTimeUTC','Distance','GlobalID'], inplace=True)
clark_co_df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Crash_Severity', 'County', 'Crash_Date',
#        'Crash_Year', 'Crash_Time', 'Primary_Street', 'Dir', 'Secondary_Street',
#        'Weather', 'Fatalities', 'Injured', 'Property_Damage_Only',
#        'Injury_Type', 'Crash_Type', 'Total_Vehicles', 'V1_Type', 'V1_Dir',
#        'V1_Driver_Age', 'V1_Lane_Num', 'V1_Action', 'V1_Driver_Factors',
#        'V1_Driver_Distracted', 'V1_Vehicle_Factors', 'V1_Most_Harmful_Event',
#        'V1_All_Events', 'V2_Type', 'V2_Dir', 'V2_Driver_Age', 'V2_Lane_Num',
#        'V2_Action', 'V2_Driver_Factors', 'V2_Driver_Distracted',
#        'V2_Vehicle_Factors', 'V2_Most_Harmful_Event', 'V2_All_Events',
#        'First_Harmful_Event', 'Nonmotorist_Factors', 'Factors_Roadway',
#        'Lighting', 'HWY_Factors', 'Agency', 'Accident_Rec_Num', 'Pedalcyclist',
#        'Pedestrian', 'Motorcyclist', 'AnimalType'],
#       dtype='object')

# %%
unk_cols = ['V1_Driver_Factors','V1_Driver_Distracted','V1_Vehicle_Factors','V1_Most_Harmful_Event',
            'V1_All_Events','V2_Type','V2_Action','V2_Driver_Factors',
            'V2_Driver_Distracted','V2_Vehicle_Factors','V2_Most_Harmful_Event','V2_All_Events',
            'First_Harmful_Event','Nonmotorist_Factors','Factors_Roadway','Lighting',
            'HWY_Factors']

for x in unk_cols:
    clark_co_df[x].fillna('Unknown', inplace=True)

clark_co_df
# Out:
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street Dir  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N   S
# 1       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573   W
# 2       2016/01/03 02:29:59+00        2016   2:30:00 AM             IR15S   S
# 3       2016/01/03 00:00:00+00        2016   9:22:00 PM      S DURANGO DR   S
# 4       2016/01/06 06:01:59+00        2016   6:02:00 AM    W ALEXANDER RD   W
# ...                        ...         ...          ...               ...  ..
# 178453  2020/12/31 13:24:00+00        2020   1:24:00 PM      E RUSSELL RD   W
# 178454  2020/12/29 20:03:59+00        2020   8:04:00 PM  S LAS VEGAS BLVD   S
# 178455  2020/12/31 01:24:00+00        2020   1:24:00 AM     W FLAMINGO RD   E
# 178456  2020/12/28 17:19:59+00        2020   5:20:00 PM   WARM SPRINGS RD   N
# 178457  2020/12/30 21:53:00+00        2020   9:53:00 PM     MEL TORME WAY   N
#
#         ...            Nonmotorist_Factors Factors_Roadway  \
# 0       ...                        Unknown             DRY
# 1       ...                        Unknown             DRY
# 2       ...                        Unknown             WET
# 3       ...  FAILURE TO YIELD RIGHT OF WAY             DRY
# 4       ...                        UNKNOWN             DRY
# ...     ...                            ...             ...
# 178453  ...                        Unknown             DRY
# 178454  ...                        Unknown             DRY
# 178455  ...                        Unknown             DRY
# 178456  ...                        Unknown             DRY
# 178457  ...                        Unknown             DRY
#
#                            Lighting                        HWY_Factors Agency  \
# 0                          DAYLIGHT                               NONE    NHP
# 1                          DAYLIGHT              WET, ICY, SNOW, SLUSH    NHP
# 2              DARK - SPOT LIGHTING                               NONE    NHP
# 3       DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 4       DARK - CONTINUOUS LIGHTING                                NONE   NLPD
# ...                             ...                                ...    ...
# 178453                     DAYLIGHT  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD
# 178454  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178455  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178456  DARK - CONTINUOUS LIGHTING                                NONE   HEPD
# 178457         DARK - SPOT LIGHTING                               NONE    NHP
#
#        Accident_Rec_Num Pedalcyclist  Pedestrian Motorcyclist AnimalType
# 0             2224407.0          NaN         NaN          NaN        NaN
# 1             2224394.0          NaN         NaN          NaN        NaN
# 2             2215025.0          NaN         NaN          NaN        NaN
# 3             2221432.0          NaN         YES          NaN        NaN
# 4             2215818.0          NaN         YES          NaN        NaN
# ...                 ...          ...         ...          ...        ...
# 178453        3145910.0          NaN         NaN          NaN        NaN
# 178454        3145748.0          NaN         NaN          NaN        NaN
# 178455        3146377.0          NaN         NaN          NaN        NaN
# 178456        3223422.0          NaN         NaN          NaN        NaN
# 178457        3147538.0          NaN         NaN          NaN        NaN
#
# [178458 rows x 49 columns]

# %%
zerolist = ['Fatalities','Injured','V1_Lane_Num','V2_Lane_Num']
for zeros in zerolist:
    clark_co_df[zeros].fillna(0, inplace=True)

clark_co_df
# Out:
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street Dir  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N   S
# 1       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573   W
# 2       2016/01/03 02:29:59+00        2016   2:30:00 AM             IR15S   S
# 3       2016/01/03 00:00:00+00        2016   9:22:00 PM      S DURANGO DR   S
# 4       2016/01/06 06:01:59+00        2016   6:02:00 AM    W ALEXANDER RD   W
# ...                        ...         ...          ...               ...  ..
# 178453  2020/12/31 13:24:00+00        2020   1:24:00 PM      E RUSSELL RD   W
# 178454  2020/12/29 20:03:59+00        2020   8:04:00 PM  S LAS VEGAS BLVD   S
# 178455  2020/12/31 01:24:00+00        2020   1:24:00 AM     W FLAMINGO RD   E
# 178456  2020/12/28 17:19:59+00        2020   5:20:00 PM   WARM SPRINGS RD   N
# 178457  2020/12/30 21:53:00+00        2020   9:53:00 PM     MEL TORME WAY   N
#
#         ...            Nonmotorist_Factors Factors_Roadway  \
# 0       ...                        Unknown             DRY
# 1       ...                        Unknown             DRY
# 2       ...                        Unknown             WET
# 3       ...  FAILURE TO YIELD RIGHT OF WAY             DRY
# 4       ...                        UNKNOWN             DRY
# ...     ...                            ...             ...
# 178453  ...                        Unknown             DRY
# 178454  ...                        Unknown             DRY
# 178455  ...                        Unknown             DRY
# 178456  ...                        Unknown             DRY
# 178457  ...                        Unknown             DRY
#
#                            Lighting                        HWY_Factors Agency  \
# 0                          DAYLIGHT                               NONE    NHP
# 1                          DAYLIGHT              WET, ICY, SNOW, SLUSH    NHP
# 2              DARK - SPOT LIGHTING                               NONE    NHP
# 3       DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 4       DARK - CONTINUOUS LIGHTING                                NONE   NLPD
# ...                             ...                                ...    ...
# 178453                     DAYLIGHT  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD
# 178454  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178455  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178456  DARK - CONTINUOUS LIGHTING                                NONE   HEPD
# 178457         DARK - SPOT LIGHTING                               NONE    NHP
#
#        Accident_Rec_Num Pedalcyclist  Pedestrian Motorcyclist AnimalType
# 0             2224407.0          NaN         NaN          NaN        NaN
# 1             2224394.0          NaN         NaN          NaN        NaN
# 2             2215025.0          NaN         NaN          NaN        NaN
# 3             2221432.0          NaN         YES          NaN        NaN
# 4             2215818.0          NaN         YES          NaN        NaN
# ...                 ...          ...         ...          ...        ...
# 178453        3145910.0          NaN         NaN          NaN        NaN
# 178454        3145748.0          NaN         NaN          NaN        NaN
# 178455        3146377.0          NaN         NaN          NaN        NaN
# 178456        3223422.0          NaN         NaN          NaN        NaN
# 178457        3147538.0          NaN         NaN          NaN        NaN
#
# [178458 rows x 49 columns]

# %%
nolist = ['Property_Damage_Only','Pedalcyclist','Pedestrian','Motorcyclist','AnimalType']

for nos in nolist:
    clark_co_df[nos].fillna('No', inplace=True)

clark_co_df
# Out:
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street Dir  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N   S
# 1       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573   W
# 2       2016/01/03 02:29:59+00        2016   2:30:00 AM             IR15S   S
# 3       2016/01/03 00:00:00+00        2016   9:22:00 PM      S DURANGO DR   S
# 4       2016/01/06 06:01:59+00        2016   6:02:00 AM    W ALEXANDER RD   W
# ...                        ...         ...          ...               ...  ..
# 178453  2020/12/31 13:24:00+00        2020   1:24:00 PM      E RUSSELL RD   W
# 178454  2020/12/29 20:03:59+00        2020   8:04:00 PM  S LAS VEGAS BLVD   S
# 178455  2020/12/31 01:24:00+00        2020   1:24:00 AM     W FLAMINGO RD   E
# 178456  2020/12/28 17:19:59+00        2020   5:20:00 PM   WARM SPRINGS RD   N
# 178457  2020/12/30 21:53:00+00        2020   9:53:00 PM     MEL TORME WAY   N
#
#         ...            Nonmotorist_Factors Factors_Roadway  \
# 0       ...                        Unknown             DRY
# 1       ...                        Unknown             DRY
# 2       ...                        Unknown             WET
# 3       ...  FAILURE TO YIELD RIGHT OF WAY             DRY
# 4       ...                        UNKNOWN             DRY
# ...     ...                            ...             ...
# 178453  ...                        Unknown             DRY
# 178454  ...                        Unknown             DRY
# 178455  ...                        Unknown             DRY
# 178456  ...                        Unknown             DRY
# 178457  ...                        Unknown             DRY
#
#                            Lighting                        HWY_Factors Agency  \
# 0                          DAYLIGHT                               NONE    NHP
# 1                          DAYLIGHT              WET, ICY, SNOW, SLUSH    NHP
# 2              DARK - SPOT LIGHTING                               NONE    NHP
# 3       DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 4       DARK - CONTINUOUS LIGHTING                                NONE   NLPD
# ...                             ...                                ...    ...
# 178453                     DAYLIGHT  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD
# 178454  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178455  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178456  DARK - CONTINUOUS LIGHTING                                NONE   HEPD
# 178457         DARK - SPOT LIGHTING                               NONE    NHP
#
#        Accident_Rec_Num Pedalcyclist  Pedestrian Motorcyclist AnimalType
# 0             2224407.0           No          No           No         No
# 1             2224394.0           No          No           No         No
# 2             2215025.0           No          No           No         No
# 3             2221432.0           No         YES           No         No
# 4             2215818.0           No         YES           No         No
# ...                 ...          ...         ...          ...        ...
# 178453        3145910.0           No          No           No         No
# 178454        3145748.0           No          No           No         No
# 178455        3146377.0           No          No           No         No
# 178456        3223422.0           No          No           No         No
# 178457        3147538.0           No          No           No         No
#
# [178458 rows x 49 columns]

# %%
ulist = ['V1_Dir','V1_Driver_Age','V2_Dir','V2_Driver_Age','Injury_Type']

for us in ulist:
    clark_co_df[us].fillna('U', inplace=True)

clark_co_df
# Out:
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                     Crash_Date  Crash_Year   Crash_Time    Primary_Street Dir  \
# 0       2016/01/04 10:27:00+00        2016  10:27:00 AM             IR15N   S
# 1       2016/01/04 07:21:59+00        2016   7:22:00 AM             SR573   W
# 2       2016/01/03 02:29:59+00        2016   2:30:00 AM             IR15S   S
# 3       2016/01/03 00:00:00+00        2016   9:22:00 PM      S DURANGO DR   S
# 4       2016/01/06 06:01:59+00        2016   6:02:00 AM    W ALEXANDER RD   W
# ...                        ...         ...          ...               ...  ..
# 178453  2020/12/31 13:24:00+00        2020   1:24:00 PM      E RUSSELL RD   W
# 178454  2020/12/29 20:03:59+00        2020   8:04:00 PM  S LAS VEGAS BLVD   S
# 178455  2020/12/31 01:24:00+00        2020   1:24:00 AM     W FLAMINGO RD   E
# 178456  2020/12/28 17:19:59+00        2020   5:20:00 PM   WARM SPRINGS RD   N
# 178457  2020/12/30 21:53:00+00        2020   9:53:00 PM     MEL TORME WAY   N
#
#         ...            Nonmotorist_Factors Factors_Roadway  \
# 0       ...                        Unknown             DRY
# 1       ...                        Unknown             DRY
# 2       ...                        Unknown             WET
# 3       ...  FAILURE TO YIELD RIGHT OF WAY             DRY
# 4       ...                        UNKNOWN             DRY
# ...     ...                            ...             ...
# 178453  ...                        Unknown             DRY
# 178454  ...                        Unknown             DRY
# 178455  ...                        Unknown             DRY
# 178456  ...                        Unknown             DRY
# 178457  ...                        Unknown             DRY
#
#                            Lighting                        HWY_Factors Agency  \
# 0                          DAYLIGHT                               NONE    NHP
# 1                          DAYLIGHT              WET, ICY, SNOW, SLUSH    NHP
# 2              DARK - SPOT LIGHTING                               NONE    NHP
# 3       DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 4       DARK - CONTINUOUS LIGHTING                                NONE   NLPD
# ...                             ...                                ...    ...
# 178453                     DAYLIGHT  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD
# 178454  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178455  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178456  DARK - CONTINUOUS LIGHTING                                NONE   HEPD
# 178457         DARK - SPOT LIGHTING                               NONE    NHP
#
#        Accident_Rec_Num Pedalcyclist  Pedestrian Motorcyclist AnimalType
# 0             2224407.0           No          No           No         No
# 1             2224394.0           No          No           No         No
# 2             2215025.0           No          No           No         No
# 3             2221432.0           No         YES           No         No
# 4             2215818.0           No         YES           No         No
# ...                 ...          ...         ...          ...        ...
# 178453        3145910.0           No          No           No         No
# 178454        3145748.0           No          No           No         No
# 178455        3146377.0           No          No           No         No
# 178456        3223422.0           No          No           No         No
# 178457        3147538.0           No          No           No         No
#
# [178458 rows x 49 columns]

# %%
clark_co_df.isnull().sum()
# Out:
# X                           0
# Y                           0
# OBJECTID                    0
# Crash_Severity              0
# County                      0
# Crash_Date                  0
# Crash_Year                  0
# Crash_Time                  0
# Primary_Street              0
# Dir                         0
# Secondary_Street            1
# Weather                   553
# Fatalities                  0
# Injured                     0
# Property_Damage_Only        0
# Injury_Type                 0
# Crash_Type                166
# Total_Vehicles              0
# V1_Type                  7687
# V1_Dir                      0
# V1_Driver_Age               0
# V1_Lane_Num                 0
# V1_Action                 387
# V1_Driver_Factors           0
# V1_Driver_Distracted        0
# V1_Vehicle_Factors          0
# V1_Most_Harmful_Event       0
# V1_All_Events               0
# V2_Type                     0
# V2_Dir                      0
# V2_Driver_Age               0
# V2_Lane_Num                 0
# V2_Action                   0
# V2_Driver_Factors           0
# V2_Driver_Distracted        0
# V2_Vehicle_Factors          0
# V2_Most_Harmful_Event       0
# V2_All_Events               0
# First_Harmful_Event         0
# Nonmotorist_Factors         0
# Factors_Roadway             0
# Lighting                    0
# HWY_Factors                 0
# Agency                    236
# Accident_Rec_Num           85
# Pedalcyclist                0
# Pedestrian                  0
# Motorcyclist                0
# AnimalType                  0
# dtype: int64

# %%
clark_co_df.iloc[:,24:].isnull().sum()
# Out:
# V1_Driver_Distracted       0
# V1_Vehicle_Factors         0
# V1_Most_Harmful_Event      0
# V1_All_Events              0
# V2_Type                    0
# V2_Dir                     0
# V2_Driver_Age              0
# V2_Lane_Num                0
# V2_Action                  0
# V2_Driver_Factors          0
# V2_Driver_Distracted       0
# V2_Vehicle_Factors         0
# V2_Most_Harmful_Event      0
# V2_All_Events              0
# First_Harmful_Event        0
# Nonmotorist_Factors        0
# Factors_Roadway            0
# Lighting                   0
# HWY_Factors                0
# Agency                   236
# Accident_Rec_Num          85
# Pedalcyclist               0
# Pedestrian                 0
# Motorcyclist               0
# AnimalType                 0
# dtype: int64

# %%
clark_co_df.dropna(inplace=True)

# %%
clark_co_df.isnull().sum()
# Out:
# X                        0
# Y                        0
# OBJECTID                 0
# Crash_Severity           0
# County                   0
# Crash_Date               0
# Crash_Year               0
# Crash_Time               0
# Primary_Street           0
# Dir                      0
# Secondary_Street         0
# Weather                  0
# Fatalities               0
# Injured                  0
# Property_Damage_Only     0
# Injury_Type              0
# Crash_Type               0
# Total_Vehicles           0
# V1_Type                  0
# V1_Dir                   0
# V1_Driver_Age            0
# V1_Lane_Num              0
# V1_Action                0
# V1_Driver_Factors        0
# V1_Driver_Distracted     0
# V1_Vehicle_Factors       0
# V1_Most_Harmful_Event    0
# V1_All_Events            0
# V2_Type                  0
# V2_Dir                   0
# V2_Driver_Age            0
# V2_Lane_Num              0
# V2_Action                0
# V2_Driver_Factors        0
# V2_Driver_Distracted     0
# V2_Vehicle_Factors       0
# V2_Most_Harmful_Event    0
# V2_All_Events            0
# First_Harmful_Event      0
# Nonmotorist_Factors      0
# Factors_Roadway          0
# Lighting                 0
# HWY_Factors              0
# Agency                   0
# Accident_Rec_Num         0
# Pedalcyclist             0
# Pedestrian               0
# Motorcyclist             0
# AnimalType               0
# dtype: int64

# %%
clark_co_df.dtypes
# Out:
# X                        float64
# Y                        float64
# OBJECTID                   int64
# Crash_Severity            object
# County                    object
# Crash_Date                object
# Crash_Year                 int64
# Crash_Time                object
# Primary_Street            object
# Dir                       object
# Secondary_Street          object
# Weather                   object
# Fatalities               float64
# Injured                  float64
# Property_Damage_Only      object
# Injury_Type               object
# Crash_Type                object
# Total_Vehicles             int64
# V1_Type                   object
# V1_Dir                    object
# V1_Driver_Age             object
# V1_Lane_Num               object
# V1_Action                 object
# V1_Driver_Factors         object
# V1_Driver_Distracted      object
# V1_Vehicle_Factors        object
# V1_Most_Harmful_Event     object
# V1_All_Events             object
# V2_Type                   object
# V2_Dir                    object
# V2_Driver_Age             object
# V2_Lane_Num               object
# V2_Action                 object
# V2_Driver_Factors         object
# V2_Driver_Distracted      object
# V2_Vehicle_Factors        object
# V2_Most_Harmful_Event     object
# V2_All_Events             object
# First_Harmful_Event       object
# Nonmotorist_Factors       object
# Factors_Roadway           object
# Lighting                  object
# HWY_Factors               object
# Agency                    object
# Accident_Rec_Num         float64
# Pedalcyclist              object
# Pedestrian                object
# Motorcyclist              object
# AnimalType                object
# dtype: object

# %%
clark_co_df['Crash_Date'] = pd.to_datetime(clark_co_df['Crash_Date'])
# clark_co_df['Crash_Year'] = pd.to_datetime(clark_co_df['Crash_Year'], format = '%Y')
# clark_co_df['Crash_Time'] = pd.to_datetime(clark_co_df['Crash_Time'], format = '%I:%M:%S %p')

# %%
clark_co_df
# Out:
#                  X          Y  OBJECTID        Crash_Severity County  \
# 0      -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY  CLARK
# 1      -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY  CLARK
# 2      -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY  CLARK
# 3      -115.278964  36.136313    663738           FATAL CRASH  CLARK
# 4      -115.162277  36.232014    663739          INJURY CRASH  CLARK
# ...            ...        ...       ...                   ...    ...
# 178453 -115.125575  36.086392    901066          INJURY CRASH  CLARK
# 178454 -115.170558  36.123567    901067  PROPERTY DAMAGE ONLY  CLARK
# 178455 -115.296210  36.114934    901068          INJURY CRASH  CLARK
# 178456 -115.033041  36.056311    901069  PROPERTY DAMAGE ONLY  CLARK
# 178457 -115.173247  36.125607    901070          INJURY CRASH  CLARK
#
#                       Crash_Date  Crash_Year   Crash_Time    Primary_Street  \
# 0      2016-01-04 10:27:00+00:00        2016  10:27:00 AM             IR15N
# 1      2016-01-04 07:21:59+00:00        2016   7:22:00 AM             SR573
# 2      2016-01-03 02:29:59+00:00        2016   2:30:00 AM             IR15S
# 3      2016-01-03 00:00:00+00:00        2016   9:22:00 PM      S DURANGO DR
# 4      2016-01-06 06:01:59+00:00        2016   6:02:00 AM    W ALEXANDER RD
# ...                          ...         ...          ...               ...
# 178453 2020-12-31 13:24:00+00:00        2020   1:24:00 PM      E RUSSELL RD
# 178454 2020-12-29 20:03:59+00:00        2020   8:04:00 PM  S LAS VEGAS BLVD
# 178455 2020-12-31 01:24:00+00:00        2020   1:24:00 AM     W FLAMINGO RD
# 178456 2020-12-28 17:19:59+00:00        2020   5:20:00 PM   WARM SPRINGS RD
# 178457 2020-12-30 21:53:00+00:00        2020   9:53:00 PM     MEL TORME WAY
#
#        Dir  ...            Nonmotorist_Factors Factors_Roadway  \
# 0        S  ...                        Unknown             DRY
# 1        W  ...                        Unknown             DRY
# 2        S  ...                        Unknown             WET
# 3        S  ...  FAILURE TO YIELD RIGHT OF WAY             DRY
# 4        W  ...                        UNKNOWN             DRY
# ...     ..  ...                            ...             ...
# 178453   W  ...                        Unknown             DRY
# 178454   S  ...                        Unknown             DRY
# 178455   E  ...                        Unknown             DRY
# 178456   N  ...                        Unknown             DRY
# 178457   N  ...                        Unknown             DRY
#
#                            Lighting                        HWY_Factors Agency  \
# 0                          DAYLIGHT                               NONE    NHP
# 1                          DAYLIGHT              WET, ICY, SNOW, SLUSH    NHP
# 2              DARK - SPOT LIGHTING                               NONE    NHP
# 3       DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 4       DARK - CONTINUOUS LIGHTING                                NONE   NLPD
# ...                             ...                                ...    ...
# 178453                     DAYLIGHT  WORK ZONE (CONST. MAINT. UTILITY)  LVMPD
# 178454  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178455  DARK - CONTINUOUS LIGHTING                                NONE  LVMPD
# 178456  DARK - CONTINUOUS LIGHTING                                NONE   HEPD
# 178457         DARK - SPOT LIGHTING                               NONE    NHP
#
#        Accident_Rec_Num Pedalcyclist  Pedestrian Motorcyclist AnimalType
# 0             2224407.0           No          No           No         No
# 1             2224394.0           No          No           No         No
# 2             2215025.0           No          No           No         No
# 3             2221432.0           No         YES           No         No
# 4             2215818.0           No         YES           No         No
# ...                 ...          ...         ...          ...        ...
# 178453        3145910.0           No          No           No         No
# 178454        3145748.0           No          No           No         No
# 178455        3146377.0           No          No           No         No
# 178456        3223422.0           No          No           No         No
# 178457        3147538.0           No          No           No         No
#
# [169820 rows x 49 columns]

# %%
clark_co_df.dtypes
# Out:
# X                                    float64
# Y                                    float64
# OBJECTID                               int64
# Crash_Severity                        object
# County                                object
# Crash_Date               datetime64[ns, UTC]
# Crash_Year                             int64
# Crash_Time                            object
# Primary_Street                        object
# Dir                                   object
# Secondary_Street                      object
# Weather                               object
# Fatalities                           float64
# Injured                              float64
# Property_Damage_Only                  object
# Injury_Type                           object
# Crash_Type                            object
# Total_Vehicles                         int64
# V1_Type                               object
# V1_Dir                                object
# V1_Driver_Age                         object
# V1_Lane_Num                           object
# V1_Action                             object
# V1_Driver_Factors                     object
# V1_Driver_Distracted                  object
# V1_Vehicle_Factors                    object
# V1_Most_Harmful_Event                 object
# V1_All_Events                         object
# V2_Type                               object
# V2_Dir                                object
# V2_Driver_Age                         object
# V2_Lane_Num                           object
# V2_Action                             object
# V2_Driver_Factors                     object
# V2_Driver_Distracted                  object
# V2_Vehicle_Factors                    object
# V2_Most_Harmful_Event                 object
# V2_All_Events                         object
# First_Harmful_Event                   object
# Nonmotorist_Factors                   object
# Factors_Roadway                       object
# Lighting                              object
# HWY_Factors                           object
# Agency                                object
# Accident_Rec_Num                     float64
# Pedalcyclist                          object
# Pedestrian                            object
# Motorcyclist                          object
# AnimalType                            object
# dtype: object

# %%
# clark_co_df.set_index('OBJECTID', inplace=True)
# clark_co_df.head(10)

# %%
cols = clark_co_df.columns
print(cols)
# Out:
# Index(['X', 'Y', 'OBJECTID', 'Crash_Severity', 'County', 'Crash_Date',
#        'Crash_Year', 'Crash_Time', 'Primary_Street', 'Dir', 'Secondary_Street',
#        'Weather', 'Fatalities', 'Injured', 'Property_Damage_Only',
#        'Injury_Type', 'Crash_Type', 'Total_Vehicles', 'V1_Type', 'V1_Dir',
#        'V1_Driver_Age', 'V1_Lane_Num', 'V1_Action', 'V1_Driver_Factors',
#        'V1_Driver_Distracted', 'V1_Vehicle_Factors', 'V1_Most_Harmful_Event',
#        'V1_All_Events', 'V2_Type', 'V2_Dir', 'V2_Driver_Age', 'V2_Lane_Num',
#        'V2_Action', 'V2_Driver_Factors', 'V2_Driver_Distracted',
#        'V2_Vehicle_Factors', 'V2_Most_Harmful_Event', 'V2_All_Events',
#        'First_Harmful_Event', 'Nonmotorist_Factors', 'Factors_Roadway',
#        'Lighting', 'HWY_Factors', 'Agency', 'Accident_Rec_Num', 'Pedalcyclist',
#        'Pedestrian', 'Motorcyclist', 'AnimalType'],
#       dtype='object')
