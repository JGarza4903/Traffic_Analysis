# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Home/Traffic_Analysis/Analysis/Nevada_population_clean_1.csv")
df.head()
# Out:
#       County  Population_2016  Population_2017  Population_2018  \
# 0  CHURCHILL            23957            24088            24574
# 1      CLARK          2140240          2183273          2228970
# 2    DOUGLAS            47805            48014            48527
# 3       ELKO            52022            52307            52470
# 4  ESMERALDA              839              858              827
#
#    Population_2019  Population_2020
# 0            25048            25363
# 1          2275884          2315963
# 2            48998            49088
# 3            52880            53006
# 4              870              886

# %%
df.tail()
# Out:
#         County  Population_2016  Population_2017  Population_2018  \
# 12    PERSHING             6582             6475             6696
# 13      STOREY             4004             4001             4027
# 14      WASHOE           449990           456864           464593
# 15  WHITE PINE             9746             9628             9532
# 16      CARSON            54323            54684            55287
#
#     Population_2019  Population_2020
# 12             6628             6573
# 13             4193             4207
# 14           472381           477082
# 15             9478             9466
# 16            55894            56034

# %%
df.isna()
# Out:
#     County  Population_2016  Population_2017  Population_2018  \
# 0    False            False            False            False
# 1    False            False            False            False
# 2    False            False            False            False
# 3    False            False            False            False
# 4    False            False            False            False
# 5    False            False            False            False
# 6    False            False            False            False
# 7    False            False            False            False
# 8    False            False            False            False
# 9    False            False            False            False
# 10   False            False            False            False
# 11   False            False            False            False
# 12   False            False            False            False
# 13   False            False            False            False
# ...

# %%
df.dtypes
# Out:
# County             object
# Population_2016     int64
# Population_2017     int64
# Population_2018     int64
# Population_2019     int64
# Population_2020     int64
# dtype: object

# %%
df = df.astype({"Population_2016":'int', "Population_2017":'int', "Population_2018":'int', "Population_2019":'int', "Population_2020":'int'}) 
df.dtypes
# Out:
# County             object
# Population_2016     int32
# Population_2017     int32
# Population_2018     int32
# Population_2019     int32
# Population_2020     int32
# dtype: object

# %%
# Save dataframe to CSV
df.to_csv('../Analysis/Nevada_population_clean_1.csv')
