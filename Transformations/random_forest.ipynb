# %%
# Initial imports
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Loading data
file_path = Path("../Analysis/cleaned_traffic_data.csv")
traffic_df = pd.read_csv(file_path)
traffic_df.head()
# Out:
#             X          Y  OBJECTID        Crash_Severity  County  \
# 0 -115.106709  36.236043    663733  PROPERTY DAMAGE ONLY   CLARK
# 1 -119.673794  39.626433    663734  PROPERTY DAMAGE ONLY  WASHOE
# 2 -115.101063  36.240200    663735  PROPERTY DAMAGE ONLY   CLARK
# 3 -119.633092  39.516952    663736  PROPERTY DAMAGE ONLY  WASHOE
# 4 -115.140570  36.192680    663737  PROPERTY DAMAGE ONLY   CLARK
#
#                   Crash_Date  Crash_Year   Crash_Time       Weather  \
# 0  2016-01-04 10:27:00+00:00        2016  10:27:00 AM        CLOUDY
# 1  2016-01-07 05:52:59+00:00        2016   5:53:00 AM          SNOW
# 2  2016-01-04 07:21:59+00:00        2016   7:22:00 AM  CLOUDY: RAIN
# 3  2016-01-06 00:20:00+00:00        2016  12:20:00 AM         CLEAR
# 4  2016-01-03 02:29:59+00:00        2016   2:30:00 AM         CLEAR
#
#    Fatalities  ...  V2_All_Events Nonmotorist_Factors Factors_Roadway  \
# 0           0  ...        Unknown             Unknown             DRY
# 1           0  ...        Unknown             Unknown         Unknown
# 2           0  ...        Unknown             Unknown             DRY
# 3           0  ...        Unknown             Unknown             DRY
# 4           0  ...        Unknown             Unknown             WET
#
#                Lighting            HWY_Factors Accident_Rec_Num  Pedalcyclist  \
# 0              DAYLIGHT                   NONE          2224407            No
# 1               Unknown                Unknown          2310434            No
# 2              DAYLIGHT  WET, ICY, SNOW, SLUSH          2224394            No
# 3    DARK - NO LIGHTING  WET, ICY, SNOW, SLUSH          2224528            No
# 4  DARK - SPOT LIGHTING                   NONE          2215025            No
#
#   Pedestrian Motorcyclist AnimalType
# 0         No           No         No
# 1         No           No         No
# 2         No           No         No
# 3         No           No         No
# 4         No           No         No
#
# [5 rows x 40 columns]

# %%
dop_columns = ['X','Y','Crash_Date','Crash_Year','Crash_Time','']
