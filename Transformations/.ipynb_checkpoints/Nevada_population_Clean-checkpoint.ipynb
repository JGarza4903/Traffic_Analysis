# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Home/Traffic_Analysis/Resources/Nevada_population_raw.csv")
df.head()
# Out:
#   COUNTY  STNAME           CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 0      1  Nevada  Churchill County        24877.0            24875.0
# 1      3  Nevada      Clark County      1951269.0          1951278.0
# 2      5  Nevada    Douglas County        46997.0            47000.0
# 3      7  Nevada       Elko County        48818.0            48942.0
# 4      9  Nevada  Esmeralda County          783.0              784.0
#
#    POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0          24816.0          24607.0          24267.0          23956.0
# 1        1952640.0        1962162.0        1989644.0        2017798.0
# 2          47037.0          46982.0          46930.0          46956.0
# 3          49093.0          49463.0          50998.0          52378.0
# 4            783.0            770.0            791.0            847.0
#
#    POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# ...

# %% [markdown]
# Summary statistics

# %%
df.shape
# Out:
# (21, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   COUNTY             19 non-null     object
#  1   STNAME             17 non-null     object
#  2   CTYNAME            17 non-null     object
#  3   CENSUS2010POP      17 non-null     float64
#  4   ESTIMATESBASE2010  17 non-null     float64
#  5   POPESTIMATE2010    17 non-null     float64
#  6   POPESTIMATE2011    17 non-null     float64
#  7   POPESTIMATE2012    17 non-null     float64
#  8   POPESTIMATE2013    17 non-null     float64
#  9   POPESTIMATE2014    17 non-null     float64
#  10  POPESTIMATE2015    17 non-null     float64
#  11  POPESTIMATE2016    17 non-null     float64
#  12  POPESTIMATE2017    17 non-null     float64
#  13  POPESTIMATE2018    17 non-null     float64
#  14  POPESTIMATE2019    17 non-null     float64
# ...

# %%
df['COUNTY'].value_counts()
# Out:
# 1                                                                                                                                            1
# 21                                                                                                                                           1
# Nevada rows copied from:                                                                                                                     1
# 510                                                                                                                                          1
# 33                                                                                                                                           1
# 31                                                                                                                                           1
# ...

# %%
df.dtypes
# Out:
# COUNTY                object
# STNAME                object
# CTYNAME               object
# CENSUS2010POP        float64
# ESTIMATESBASE2010    float64
# POPESTIMATE2010      float64
# POPESTIMATE2011      float64
# POPESTIMATE2012      float64
# POPESTIMATE2013      float64
# POPESTIMATE2014      float64
# POPESTIMATE2015      float64
# POPESTIMATE2016      float64
# POPESTIMATE2017      float64
# POPESTIMATE2018      float64
# POPESTIMATE2019      float64
# POPESTIMATE042020    float64
# POPESTIMATE2020      float64
# dtype: object

# %%
df.head(5)
# Out:
#   COUNTY  STNAME           CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 0      1  Nevada  Churchill County        24877.0            24875.0
# 1      3  Nevada      Clark County      1951269.0          1951278.0
# 2      5  Nevada    Douglas County        46997.0            47000.0
# 3      7  Nevada       Elko County        48818.0            48942.0
# 4      9  Nevada  Esmeralda County          783.0              784.0
#
#    POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0          24816.0          24607.0          24267.0          23956.0
# 1        1952640.0        1962162.0        1989644.0        2017798.0
# 2          47037.0          46982.0          46930.0          46956.0
# 3          49093.0          49463.0          50998.0          52378.0
# 4            783.0            770.0            791.0            847.0
#
#    POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# ...

# %%
# drop columns not needed
drop_df = df.drop(['COUNTY','STNAME','CENSUS2010POP','ESTIMATESBASE2010','POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015','POPESTIMATE042020'], axis=1)

# %%
drop_df.head()
# Out:
#             CTYNAME  POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  \
# 0  Churchill County          23957.0          24088.0          24574.0
# 1      Clark County        2140240.0        2183273.0        2228970.0
# 2    Douglas County          47805.0          48014.0          48527.0
# 3       Elko County          52022.0          52307.0          52470.0
# 4  Esmeralda County            839.0            858.0            827.0
#
#    POPESTIMATE2019  POPESTIMATE2020
# 0          25048.0          25363.0
# 1        2275884.0        2315963.0
# 2          48998.0          49088.0
# 3          52880.0          53006.0
# 4            870.0            886.0

# %%
# rename columns to match traffic_data and formatting
rename_df = drop_df.rename(columns={'CTYNAME': 'County', 'POPESTIMATE2016': 'Population_2016', 'POPESTIMATE2017': 'Population_2017', 'POPESTIMATE2018': 'Population_2018', 'POPESTIMATE2019': 'Population_2019', 'POPESTIMATE2020': 'Population_2020'})

# %%
rename_df.head()
# Out:
#              County  Population_2016  Population_2017  Population_2018  \
# 0  Churchill County          23957.0          24088.0          24574.0
# 1      Clark County        2140240.0        2183273.0        2228970.0
# 2    Douglas County          47805.0          48014.0          48527.0
# 3       Elko County          52022.0          52307.0          52470.0
# 4  Esmeralda County            839.0            858.0            827.0
#
#    Population_2019  Population_2020
# 0          25048.0          25363.0
# 1        2275884.0        2315963.0
# 2          48998.0          49088.0
# 3          52880.0          53006.0
# 4            870.0            886.0

# %%
# Rename contents of County column to match traffic_data County column
rename_df.County.unique()
# Out:
# array(['Churchill County', 'Clark County', 'Douglas County',
#        'Elko County', 'Esmeralda County', 'Eureka County',
#        'Humboldt County', 'Lander County', 'Lincoln County',
#        'Lyon County', 'Mineral County', 'Nye County', 'Pershing County',
#        'Storey County', 'Washoe County', 'White Pine County',
#        'Carson City', nan], dtype=object)

# %%
county_df = rename_df.replace({'County' : {'Churchill County': 'CHURCHILL', 'Clark County': 'CLARK', 'Douglas County': 'DOUGLAS',
       'Elko County': 'ELKO', 'Esmeralda County': 'ESMERALDA', 'Eureka County': 'EUREKA',
       'Humboldt County': 'HUMBOLDT', 'Lander County': 'LANDER', 'Lincoln County': 'LINCOLN',
       'Lyon County': 'LYON', 'Mineral County': 'MINERAL', 'Nye County': 'NYE', 'Pershing County': 'PERSHING',
       'Storey County': 'STOREY', 'Washoe County': 'WASHOE', 'White Pine County': 'WHITE PINE',
       'Carson City': 'CARSON'}})
county_df.head()
# Out:
#       County  Population_2016  Population_2017  Population_2018  \
# 0  CHURCHILL          23957.0          24088.0          24574.0
# 1      CLARK        2140240.0        2183273.0        2228970.0
# 2    DOUGLAS          47805.0          48014.0          48527.0
# 3       ELKO          52022.0          52307.0          52470.0
# 4  ESMERALDA            839.0            858.0            827.0
#
#    Population_2019  Population_2020
# 0          25048.0          25363.0
# 1        2275884.0        2315963.0
# 2          48998.0          49088.0
# 3          52880.0          53006.0
# 4            870.0            886.0

# %%
county_df.isna()
# Out:
#     County  Population_2016  Population_2017  Population_2018  \
# 0    False            False            False            False
# 1    False            False            False            False
# 2    False            False            False            False
# 3    False            False            False            False
# 4    False            False            False            False
# 5    False            False            False            False
# 6    False            False            False            False
# 7    False            False            False            False
# 8    False            False            False            False
# 9    False            False            False            False
# 10   False            False            False            False
# 11   False            False            False            False
# 12   False            False            False            False
# 13   False            False            False            False
# ...

# %%
# I used fillna because dropna wasn't working?
county_df = county_df.fillna(0)

# %%
county_df.tail()
# Out:
#     County  Population_2016  Population_2017  Population_2018  \
# 16  CARSON          54323.0          54684.0          55287.0
# 17       0              0.0              0.0              0.0
# 18       0              0.0              0.0              0.0
# 19       0              0.0              0.0              0.0
# 20       0              0.0              0.0              0.0
#
#     Population_2019  Population_2020
# 16          55894.0          56034.0
# 17              0.0              0.0
# 18              0.0              0.0
# 19              0.0              0.0
# 20              0.0              0.0

# %%
county_df.head()
# Out:
#       County  Population_2016  Population_2017  Population_2018  \
# 0  CHURCHILL          23957.0          24088.0          24574.0
# 1      CLARK        2140240.0        2183273.0        2228970.0
# 2    DOUGLAS          47805.0          48014.0          48527.0
# 3       ELKO          52022.0          52307.0          52470.0
# 4  ESMERALDA            839.0            858.0            827.0
#
#    Population_2019  Population_2020
# 0          25048.0          25363.0
# 1        2275884.0        2315963.0
# 2          48998.0          49088.0
# 3          52880.0          53006.0
# 4            870.0            886.0

# %%
county_df.dtypes
# Out:
# County              object
# Population_2016    float64
# Population_2017    float64
# Population_2018    float64
# Population_2019    float64
# Population_2020    float64
# dtype: object

# %%
county_df['Population_2016 '] = county_df['Population_2016 '].astype(int)
county_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population_2016 '
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Save dataframe to CSV
# county_df.to_csv('../Analysis/Nevada_population_clean.csv')
